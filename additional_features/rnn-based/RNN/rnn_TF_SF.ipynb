# %%
import warnings
import gc
import tensorflow as tf
from tensorflow import keras
from random import choice
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Concatenate, Embedding, Flatten, Activation, Dropout
from tensorflow.keras.layers import SimpleRNN as RNN
from sklearn.model_selection import KFold
from tensorflow.python.client import device_lib
warnings.filterwarnings('ignore')
import random

# %%
MAXLENGTH = 13
EMBEDDING_DIM = 128
DENSE_NEURON = 16
RNN_NEURON = 32

# %%
FEATURES_SIZE = 39
CHAPTER_SIZE = 38
SUB_CHAPTER_SIZE = 223
QUESTION_SIZE = 1069

# %%
import torch
X = np.array(grouped_data.keys())
kfold = KFold(n_splits=5, shuffle=True)
train_losses = list()
train_aucs = list()
val_losses = list()
val_aucs = list()
train_eval = list()
test_eval = list()
for train, test in kfold.split(X):
    users_train, users_test =  X[train], X[test]
    n = len(users_test)//2
    users_test, users_val = users_test[:n], users_test[n: ]
    train_data_space = SPACE_DATASET(grouped_data[users_train], MAXLENGTH)
    val_data_space = SPACE_DATASET(grouped_data[users_val], MAXLENGTH)
    test_data_space = SPACE_DATASET(grouped_data[users_test], MAXLENGTH)
    #construct training input
    train_chapter=[]
    train_sub_chapter=[]
    train_question = []
    train_features=[]
    train_labels=[]
    for i in range(len(users_train)):
        user = train_data_space.__getitem__(i)
        train_chapter.append(user[0])
        train_sub_chapter.append(user[1]) 
        train_question.append(user[2])
        train_features.append(user[3])
        train_labels.append(user[4])
    train_chapter = np.array(train_chapter)
    train_sub_chapter = np.array(train_sub_chapter)
    train_question = np.array(train_question)
    train_features = np.array(train_features)
    train_labels= np.array(train_labels)[..., np.newaxis]

    #construct validation input
    val_chapter=[]
    val_sub_chapter=[]
    val_question = []
    val_features=[]
    val_labels=[]
    for i in range(len(users_val)):
        user = val_data_space.__getitem__(i)
        val_chapter.append(user[0])
        val_sub_chapter.append(user[1]) 
        val_question.append(user[2])
        val_features.append(user[3])
        val_labels.append(user[4])
    val_chapter = np.array(val_chapter)
    val_sub_chapter = np.array(val_sub_chapter)
    val_features = np.array(val_features)
    val_question = np.array(val_question)
    #val_shifted_t = np.array(val_shifted_t)
    val_labels= np.array(val_labels)[..., np.newaxis]

    # construct test input
    test_chapter=[]
    test_sub_chapter=[]
    test_features=[]
    test_question=[]
    test_labels=[]
    for i in range(len(users_test)):
        user = test_data_space.__getitem__(i)
        test_chapter.append(user[0])
        test_sub_chapter.append(user[1]) 
        test_question.append(user[2])
        test_features.append(user[3])
        test_labels.append(user[4])
    test_chapter = np.array(test_chapter)
    test_sub_chapter = np.array(test_sub_chapter)
    test_features = np.array(test_features)
    test_question = np.array(test_question)
    test_labels= np.array(test_labels)[..., np.newaxis]

    # define loss function and evaluation metrics
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    acc = tf.keras.metrics.Accuracy()
    auc = tf.keras.metrics.AUC()

    def masked_bce(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return bce(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_acc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      flat_pred = (flat_pred >= 0.5)
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return acc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_auc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return auc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    # input layer
    input_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_sub_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_ques =  tf.keras.Input(shape=(MAXLENGTH))
    input_features = tf.keras.Input(shape=(MAXLENGTH, FEATURES_SIZE))

    # embedding layer for categorical features
    embedding_chap = Embedding(input_dim = CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_chap)
    embedding_sub_chap = Embedding(input_dim = SUB_CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_sub_chap) 
    embedding_ques = Embedding(input_dim = QUESTION_SIZE, output_dim = EMBEDDING_DIM)(input_ques)       
    # dense layer for numeric features
    dense_features = Dense(EMBEDDING_DIM,input_shape = (None, MAXLENGTH))(input_features)

    # definr RNN layers
    RNN_chap = RNN(RNN_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_chap)
    RNN_sub_chap = RNN(RNN_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_sub_chap)
    RNN_ques = RNN(RNN_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_ques)
    RNN_features = RNN(RNN_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(dense_features)

    RNN_output = tf.concat([RNN_chap, RNN_sub_chap, RNN_ques, RNN_features], axis = 2)

    dense1 = Dense(256, input_shape = (None, 4*EMBEDDING_DIM), activation='relu')(RNN_output)
    dropout1 = Dropout(0.1)(dense1)
    dense2 = Dense(64, input_shape = (None, 256), activation='relu')(dropout1)
    dropout2 = Dropout(0.1)(dense2)
    pred = Dense(1, input_shape = (None, 64), activation='sigmoid')(dropout2)

    model = tf.keras.Model(
        inputs=[input_chap, input_sub_chap,input_ques, input_features],
        outputs=pred,
        name='RNN_model'
    )

    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt_adam = Adam(learning_rate = 0.005)
    model.compile(
        optimizer=opt_adam,
        loss= masked_bce,
        metrics = [masked_acc, masked_auc]
    )

    history = model.fit(
      [train_chapter, train_sub_chapter, train_question, train_features],
      train_labels,
      batch_size = 64,
      epochs = 100,
      validation_data=([val_chapter, val_sub_chapter, val_question, val_features], val_labels),
      callbacks=[callback]
    )
    val_losses.append(list(history.history['val_loss']))
    train_losses.append(list(history.history['loss']))
    val_aucs.append(list(history.history['val_masked_auc']))
    train_aucs.append(list(history.history['masked_auc']))
    train_score = model.evaluate([train_chapter, train_sub_chapter, train_question, train_features], train_labels)
    train_eval.append(train_score)
    test_score = model.evaluate([test_chapter, test_sub_chapter, test_question, test_features], test_labels)
    test_eval.append(test_score)
    print("Test: ", test_score)
    def reset_weights(model):
      for layer in model.layers: 
        if isinstance(layer, tf.keras.Model):
          reset_weights(layer)
          continue
        for k, initializer in layer.__dict__.items():
          if "initializer" not in k:
            continue
          # find the corresponding variable
          var = getattr(layer, k.replace("_initializer", ""))
          var.assign(initializer(var.shape, var.dtype))
    reset_weights(model)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 6s 147ms/step - loss: 0.6203 - masked_acc: 0.5489 - masked_auc: 0.5212 - val_loss: 0.5168 - val_masked_acc: 0.7089 - val_masked_auc: 0.5829
# Epoch 2/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.4826 - masked_acc: 0.7193 - masked_auc: 0.6308 - val_loss: 0.5062 - val_masked_acc: 0.7380 - val_masked_auc: 0.6987
# Epoch 3/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.3837 - masked_acc: 0.7480 - masked_auc: 0.7263 - val_loss: 0.5535 - val_masked_acc: 0.7624 - val_masked_auc: 0.7637
# Epoch 4/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.3226 - masked_acc: 0.7705 - masked_auc: 0.7795 - val_loss: 0.7021 - val_masked_acc: 0.7837 - val_masked_auc: 0.8046
# Epoch 5/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2623 - masked_acc: 0.7901 - masked_auc: 0.8163 - val_loss: 0.8934 - val_masked_acc: 0.8001 - val_masked_auc: 0.8326
# Epoch 6/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2316 - masked_acc: 0.8050 - masked_auc: 0.8404 - val_loss: 0.8939 - val_masked_acc: 0.8135 - val_masked_auc: 0.8531
# Epoch 7/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.2002 - masked_acc: 0.8178 - masked_auc: 0.8595 - val_loss: 1.0114 - val_masked_acc: 0.8243 - val_masked_auc: 0.8680
# Epoch 8/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1847 - masked_acc: 0.8277 - masked_auc: 0.8725 - val_loss: 1.1502 - val_masked_acc: 0.8331 - val_masked_auc: 0.8789
# Epoch 9/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1615 - masked_acc: 0.8362 - masked_auc: 0.8828 - val_loss: 1.3158 - val_masked_acc: 0.8408 - val_masked_auc: 0.8882
# Epoch 10/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1482 - masked_acc: 0.8434 - masked_auc: 0.8914 - val_loss: 1.4799 - val_masked_acc: 0.8476 - val_masked_auc: 0.8959
# Epoch 11/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1372 - masked_acc: 0.8498 - masked_auc: 0.8985 - val_loss: 1.5836 - val_masked_acc: 0.8533 - val_masked_auc: 0.9020
# Epoch 12/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1288 - masked_acc: 0.8553 - masked_auc: 0.9043 - val_loss: 1.4259 - val_masked_acc: 0.8583 - val_masked_auc: 0.9073
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1119 - masked_acc: 0.8617 - masked_auc: 0.9112
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2084 - masked_acc: 0.8638 - masked_auc: 0.9130
# Test:  [1.2083858251571655, 0.863823413848877, 0.9129694700241089]
# Epoch 1/100
# 14/14 [==============================] - 5s 104ms/step - loss: 0.5889 - masked_acc: 0.6452 - masked_auc: 0.5357 - val_loss: 0.5397 - val_masked_acc: 0.7305 - val_masked_auc: 0.6379
# Epoch 2/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.4444 - masked_acc: 0.7394 - masked_auc: 0.6838 - val_loss: 0.5624 - val_masked_acc: 0.7547 - val_masked_auc: 0.7370
# Epoch 3/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.3438 - masked_acc: 0.7648 - masked_auc: 0.7631 - val_loss: 0.6053 - val_masked_acc: 0.7777 - val_masked_auc: 0.7931
# Epoch 4/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2819 - masked_acc: 0.7859 - masked_auc: 0.8083 - val_loss: 0.8262 - val_masked_acc: 0.7969 - val_masked_auc: 0.8272
# Epoch 5/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2414 - masked_acc: 0.8030 - masked_auc: 0.8374 - val_loss: 0.9375 - val_masked_acc: 0.8125 - val_masked_auc: 0.8503
# Epoch 6/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2047 - masked_acc: 0.8174 - masked_auc: 0.8576 - val_loss: 1.0566 - val_masked_acc: 0.8242 - val_masked_auc: 0.8668
# Epoch 7/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1919 - masked_acc: 0.8281 - masked_auc: 0.8720 - val_loss: 1.2734 - val_masked_acc: 0.8342 - val_masked_auc: 0.8789
# Epoch 8/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1725 - masked_acc: 0.8375 - masked_auc: 0.8831 - val_loss: 1.3970 - val_masked_acc: 0.8427 - val_masked_auc: 0.8887
# Epoch 9/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1418 - masked_acc: 0.8457 - masked_auc: 0.8924 - val_loss: 1.5435 - val_masked_acc: 0.8500 - val_masked_auc: 0.8966
# Epoch 10/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1361 - masked_acc: 0.8525 - masked_auc: 0.8994 - val_loss: 1.5295 - val_masked_acc: 0.8559 - val_masked_auc: 0.9028
# Epoch 11/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1314 - masked_acc: 0.8580 - masked_auc: 0.9052 - val_loss: 1.5721 - val_masked_acc: 0.8612 - val_masked_auc: 0.9082
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1047 - masked_acc: 0.8650 - masked_auc: 0.9125
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4808 - masked_acc: 0.8672 - masked_auc: 0.9144
# Test:  [1.4807746410369873, 0.8672028183937073, 0.9143714904785156]
# Epoch 1/100
# 14/14 [==============================] - 5s 131ms/step - loss: 0.5975 - masked_acc: 0.7080 - masked_auc: 0.5126 - val_loss: 0.5272 - val_masked_acc: 0.7353 - val_masked_auc: 0.6027
# Epoch 2/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.4573 - masked_acc: 0.7407 - masked_auc: 0.6516 - val_loss: 0.5395 - val_masked_acc: 0.7492 - val_masked_auc: 0.7122
# Epoch 3/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.3773 - masked_acc: 0.7581 - masked_auc: 0.7381 - val_loss: 0.5873 - val_masked_acc: 0.7708 - val_masked_auc: 0.7738
# Epoch 4/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.2955 - masked_acc: 0.7791 - masked_auc: 0.7903 - val_loss: 0.7440 - val_masked_acc: 0.7913 - val_masked_auc: 0.8148
# Epoch 5/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.2566 - masked_acc: 0.7970 - masked_auc: 0.8254 - val_loss: 0.8743 - val_masked_acc: 0.8065 - val_masked_auc: 0.8415
# Epoch 6/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.2102 - masked_acc: 0.8117 - masked_auc: 0.8497 - val_loss: 1.0234 - val_masked_acc: 0.8196 - val_masked_auc: 0.8609
# Epoch 7/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1964 - masked_acc: 0.8234 - masked_auc: 0.8664 - val_loss: 1.0959 - val_masked_acc: 0.8293 - val_masked_auc: 0.8748
# Epoch 8/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1742 - masked_acc: 0.8327 - masked_auc: 0.8794 - val_loss: 1.2273 - val_masked_acc: 0.8378 - val_masked_auc: 0.8858
# Epoch 9/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1580 - masked_acc: 0.8407 - masked_auc: 0.8893 - val_loss: 1.3943 - val_masked_acc: 0.8454 - val_masked_auc: 0.8948
# Epoch 10/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1387 - masked_acc: 0.8480 - masked_auc: 0.8979 - val_loss: 1.6248 - val_masked_acc: 0.8521 - val_masked_auc: 0.9022
# Epoch 11/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.1166 - masked_acc: 0.8545 - masked_auc: 0.9049 - val_loss: 1.8640 - val_masked_acc: 0.8582 - val_masked_auc: 0.9086
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0975 - masked_acc: 0.8621 - masked_auc: 0.9129
# 4/4 [==============================] - 0s 6ms/step - loss: 1.5195 - masked_acc: 0.8646 - masked_auc: 0.9149
# Test:  [1.5195051431655884, 0.864589512348175, 0.9149303436279297]
# Epoch 1/100
# 14/14 [==============================] - 5s 100ms/step - loss: 0.5976 - masked_acc: 0.6938 - masked_auc: 0.5228 - val_loss: 0.5608 - val_masked_acc: 0.7313 - val_masked_auc: 0.5910
# Epoch 2/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.4748 - masked_acc: 0.7322 - masked_auc: 0.6383 - val_loss: 0.5900 - val_masked_acc: 0.7455 - val_masked_auc: 0.7059
# Epoch 3/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.3947 - masked_acc: 0.7517 - masked_auc: 0.7303 - val_loss: 0.6236 - val_masked_acc: 0.7650 - val_masked_auc: 0.7669
# Epoch 4/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.3204 - masked_acc: 0.7721 - masked_auc: 0.7819 - val_loss: 0.7186 - val_masked_acc: 0.7837 - val_masked_auc: 0.8067
# Epoch 5/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2622 - masked_acc: 0.7899 - masked_auc: 0.8178 - val_loss: 0.8110 - val_masked_acc: 0.7990 - val_masked_auc: 0.8340
# Epoch 6/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.2248 - masked_acc: 0.8041 - masked_auc: 0.8419 - val_loss: 0.8485 - val_masked_acc: 0.8120 - val_masked_auc: 0.8541
# Epoch 7/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2154 - masked_acc: 0.8156 - masked_auc: 0.8597 - val_loss: 1.0409 - val_masked_acc: 0.8220 - val_masked_auc: 0.8684
# Epoch 8/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1804 - masked_acc: 0.8254 - masked_auc: 0.8731 - val_loss: 1.1762 - val_masked_acc: 0.8309 - val_masked_auc: 0.8799
# Epoch 9/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1636 - masked_acc: 0.8340 - masked_auc: 0.8836 - val_loss: 1.2598 - val_masked_acc: 0.8388 - val_masked_auc: 0.8893
# Epoch 10/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1514 - masked_acc: 0.8414 - masked_auc: 0.8922 - val_loss: 1.3545 - val_masked_acc: 0.8454 - val_masked_auc: 0.8965
# Epoch 11/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.1388 - masked_acc: 0.8477 - masked_auc: 0.8992 - val_loss: 1.4280 - val_masked_acc: 0.8513 - val_masked_auc: 0.9028
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1141 - masked_acc: 0.8552 - masked_auc: 0.9072
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4321 - masked_acc: 0.8579 - masked_auc: 0.9092
# Test:  [1.4321104288101196, 0.8578858375549316, 0.9091631770133972]
# Epoch 1/100
# 14/14 [==============================] - 5s 106ms/step - loss: 0.5926 - masked_acc: 0.6608 - masked_auc: 0.5200 - val_loss: 0.5265 - val_masked_acc: 0.7309 - val_masked_auc: 0.6119
# Epoch 2/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.4692 - masked_acc: 0.7337 - masked_auc: 0.6583 - val_loss: 0.5513 - val_masked_acc: 0.7476 - val_masked_auc: 0.7203
# Epoch 3/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.3747 - masked_acc: 0.7566 - masked_auc: 0.7448 - val_loss: 0.6302 - val_masked_acc: 0.7708 - val_masked_auc: 0.7780
# Epoch 4/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2957 - masked_acc: 0.7788 - masked_auc: 0.7933 - val_loss: 0.7574 - val_masked_acc: 0.7899 - val_masked_auc: 0.8144
# Epoch 5/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.2500 - masked_acc: 0.7966 - masked_auc: 0.8251 - val_loss: 0.8589 - val_masked_acc: 0.8057 - val_masked_auc: 0.8403
# Epoch 6/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2141 - masked_acc: 0.8108 - masked_auc: 0.8483 - val_loss: 0.9546 - val_masked_acc: 0.8187 - val_masked_auc: 0.8590
# Epoch 7/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2043 - masked_acc: 0.8226 - masked_auc: 0.8644 - val_loss: 1.0750 - val_masked_acc: 0.8286 - val_masked_auc: 0.8721
# Epoch 8/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1643 - masked_acc: 0.8322 - masked_auc: 0.8769 - val_loss: 1.3094 - val_masked_acc: 0.8378 - val_masked_auc: 0.8831
# Epoch 9/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1525 - masked_acc: 0.8407 - masked_auc: 0.8867 - val_loss: 1.4436 - val_masked_acc: 0.8457 - val_masked_auc: 0.8922
# Epoch 10/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1224 - masked_acc: 0.8485 - masked_auc: 0.8956 - val_loss: 1.5359 - val_masked_acc: 0.8529 - val_masked_auc: 0.8999
# Epoch 11/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1147 - masked_acc: 0.8553 - masked_auc: 0.9025 - val_loss: 1.7505 - val_masked_acc: 0.8592 - val_masked_auc: 0.9062
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0957 - masked_acc: 0.8631 - masked_auc: 0.9107
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6493 - masked_acc: 0.8654 - masked_auc: 0.9124
# Test:  [1.6492809057235718, 0.8654217720031738, 0.9124323129653931]

# %%
t_eval = np.array(test_eval)
print("test avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("test avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("test avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# test avg loss:  1.4580113887786865 +/- 0.1441301199159681
# test avg acc:  0.863784670829773 +/- 0.0031562426369475725
# test avg auc:  0.9127733588218689 +/- 0.0020196431771794107

# %%
t_eval = np.array(train_eval)
print("train avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("train avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("train avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# train avg loss:  0.1047824501991272 +/- 0.007382948258543136
# train avg acc:  0.8614279866218567 +/- 0.003295721526649276
# train avg auc:  0.9108965516090393 +/- 0.0020312399253287006
