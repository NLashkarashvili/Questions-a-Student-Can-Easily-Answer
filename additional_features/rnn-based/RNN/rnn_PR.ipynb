# %%
import warnings
import tensorflow as tf
from tensorflow import keras
from random import choice
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Concatenate, Embedding, Flatten, Activation, Dropout
from tensorflow.keras.layers import SimpleRNN as RNN
from sklearn.model_selection import KFold
from tensorflow.python.client import device_lib
warnings.filterwarnings('ignore')
import random

# %%
#SETTINGS -> can be modified at any time
MAXLENGTH = 13
EMBEDDING_DIM = 128
DENSE_NEURON = 16
RNN_NEURON = 32

# %%
CHAPTER_SIZE = 38
SUB_CHAPTER_SIZE = 223
QUESTION_SIZE = 1069

# %%
# 5 fold cross validation with RNN-based model
import torch
X = np.array(grouped_data.keys())
kfold = KFold(n_splits=5, shuffle=True)
train_losses = list()
train_aucs = list()
val_losses = list()
val_aucs = list()
train_eval = list()
test_eval = list()
for train, test in kfold.split(X):
    users_train, users_test =  X[train], X[test]
    n = len(users_test)//2
    users_test, users_val = users_test[:n], users_test[n: ]
    train_data_space = SPACE_DATASET(grouped_data[users_train], MAXLENGTH)
    val_data_space = SPACE_DATASET(grouped_data[users_val], MAXLENGTH)
    test_data_space = SPACE_DATASET(grouped_data[users_test], MAXLENGTH)
    #construct training input
    train_chapter=[]
    train_sub_chapter=[]
    train_question = []
    train_shifted_t = []
    train_labels=[]
    for i in range(len(users_train)):
        user = train_data_space.__getitem__(i)
        train_chapter.append(user[0])
        train_sub_chapter.append(user[1]) 
        train_question.append(user[2])
        train_shifted_t.append(user[3])
        train_labels.append(user[4])
    train_chapter = np.array(train_chapter)
    train_sub_chapter = np.array(train_sub_chapter)
    train_question = np.array(train_question)
    train_shifted_t = np.array(train_shifted_t)
    train_labels= np.array(train_labels)[..., np.newaxis]

    #construct validation input
    val_chapter=[]
    val_sub_chapter=[]
    val_question = []
    val_shifted_t = []
    val_labels=[]
    for i in range(len(users_val)):
        user = val_data_space.__getitem__(i)
        val_chapter.append(user[0])
        val_sub_chapter.append(user[1]) 
        val_question.append(user[2])
        val_shifted_t.append(user[3])
        val_labels.append(user[4])
    val_chapter = np.array(val_chapter)
    val_sub_chapter = np.array(val_sub_chapter)
    val_question = np.array(val_question)
    val_shifted_t = np.array(val_shifted_t)
    val_labels= np.array(val_labels)[..., np.newaxis]

    # construct test input
    test_chapter=[]
    test_sub_chapter=[]
    test_question=[]
    test_shifted_t = []
    test_labels=[]
    for i in range(len(users_test)):
        user = test_data_space.__getitem__(i)
        test_chapter.append(user[0])
        test_sub_chapter.append(user[1]) 
        test_question.append(user[2])
        test_shifted_t.append(user[3])
        test_labels.append(user[4])
    test_chapter = np.array(test_chapter)
    test_sub_chapter = np.array(test_sub_chapter)
    test_question = np.array(test_question)
    test_shifted_t = np.array(test_shifted_t)
    test_labels= np.array(test_labels)[..., np.newaxis]

    # define loss function and evaluation metrics
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    acc = tf.keras.metrics.Accuracy()
    auc = tf.keras.metrics.AUC()

    def masked_bce(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return bce(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_acc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      flat_pred = (flat_pred >= 0.5)
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return acc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_auc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return auc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    # input layer
    input_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_sub_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_ques =  tf.keras.Input(shape=(MAXLENGTH))
    input_shifted = tf.keras.Input(shape=(MAXLENGTH))

    # embedding layer for categorical features
    embedding_chap = Embedding(input_dim = CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_chap)
    embedding_sub_chap = Embedding(input_dim = SUB_CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_sub_chap) 
    embedding_ques = Embedding(input_dim = QUESTION_SIZE, output_dim = EMBEDDING_DIM)(input_ques)       
    embedding_shifted = Embedding(input_dim = 3, output_dim = EMBEDDING_DIM)(input_shifted)

    # definr RNN layers
    RNN_chap = RNN(RNN_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_chap)
    RNN_sub_chap = RNN(RNN_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_sub_chap)
    RNN_ques = RNN(RNN_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_ques)
    RNN_shif = RNN(RNN_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_shifted)

    RNN_output = tf.concat([RNN_chap, RNN_sub_chap, RNN_ques, RNN_shif], axis = 2)

    dense1 = Dense(256, input_shape = (None, 4*EMBEDDING_DIM), activation='relu')(RNN_output)
    dropout1 = Dropout(0.1)(dense1)
    dense2 = Dense(64, input_shape = (None, 256), activation='relu')(dropout1)
    dropout2 = Dropout(0.1)(dense2)
    pred = Dense(1, input_shape = (None, 64), activation='sigmoid')(dropout2)

    model = tf.keras.Model(
        inputs=[input_chap, input_sub_chap,input_ques, input_shifted],
        outputs=pred,
        name='RNN_model'
    )

    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt_adam = Adam(learning_rate = 0.005)
    model.compile(
        optimizer=opt_adam,
        loss= masked_bce,
        metrics = [masked_acc, masked_auc]
    )

    history = model.fit(
      [train_chapter, train_sub_chapter, train_question, train_shifted_t],
      train_labels,
      batch_size = 64,
      epochs = 100,
      validation_data=([val_chapter, val_sub_chapter, val_question, val_shifted_t], val_labels),
      callbacks=[callback]
    )
    val_losses.append(list(history.history['val_loss']))
    train_losses.append(list(history.history['loss']))
    val_aucs.append(list(history.history['val_masked_auc']))
    train_aucs.append(list(history.history['masked_auc']))
    train_score = model.evaluate([train_chapter, train_sub_chapter, train_question, train_shifted_t], train_labels)
    train_eval.append(train_score)
    test_score = model.evaluate([test_chapter, test_sub_chapter, test_question, test_shifted_t], test_labels)
    test_eval.append(test_score)
    print("Test: ", test_score)
    def reset_weights(model):
      for layer in model.layers: 
        if isinstance(layer, tf.keras.Model):
          reset_weights(layer)
          continue
        for k, initializer in layer.__dict__.items():
          if "initializer" not in k:
            continue
          # find the corresponding variable
          var = getattr(layer, k.replace("_initializer", ""))
          var.assign(initializer(var.shape, var.dtype))
    reset_weights(model)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 6s 150ms/step - loss: 0.5931 - masked_acc: 0.6459 - masked_auc: 0.5418 - val_loss: 0.4926 - val_masked_acc: 0.7311 - val_masked_auc: 0.6693
# Epoch 2/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.4291 - masked_acc: 0.7411 - masked_auc: 0.7101 - val_loss: 0.5542 - val_masked_acc: 0.7613 - val_masked_auc: 0.7654
# Epoch 3/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.3302 - masked_acc: 0.7715 - masked_auc: 0.7866 - val_loss: 0.6131 - val_masked_acc: 0.7861 - val_masked_auc: 0.8158
# Epoch 4/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2706 - masked_acc: 0.7939 - masked_auc: 0.8290 - val_loss: 0.7216 - val_masked_acc: 0.8052 - val_masked_auc: 0.8470
# Epoch 5/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2289 - masked_acc: 0.8114 - masked_auc: 0.8558 - val_loss: 0.9189 - val_masked_acc: 0.8208 - val_masked_auc: 0.8682
# Epoch 6/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1985 - masked_acc: 0.8252 - masked_auc: 0.8743 - val_loss: 0.9822 - val_masked_acc: 0.8321 - val_masked_auc: 0.8833
# Epoch 7/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1820 - masked_acc: 0.8357 - masked_auc: 0.8876 - val_loss: 1.0448 - val_masked_acc: 0.8415 - val_masked_auc: 0.8944
# Epoch 8/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1714 - masked_acc: 0.8445 - masked_auc: 0.8979 - val_loss: 1.1817 - val_masked_acc: 0.8490 - val_masked_auc: 0.9026
# Epoch 9/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1542 - masked_acc: 0.8515 - masked_auc: 0.9054 - val_loss: 1.2202 - val_masked_acc: 0.8557 - val_masked_auc: 0.9094
# Epoch 10/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1297 - masked_acc: 0.8582 - masked_auc: 0.9122 - val_loss: 1.2736 - val_masked_acc: 0.8618 - val_masked_auc: 0.9154
# Epoch 11/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.1252 - masked_acc: 0.8639 - masked_auc: 0.9175 - val_loss: 1.3919 - val_masked_acc: 0.8669 - val_masked_auc: 0.9200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1090 - masked_acc: 0.8702 - masked_auc: 0.9235
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3573 - masked_acc: 0.8721 - masked_auc: 0.9248
# Test:  [1.3573448657989502, 0.8721054196357727, 0.9248316287994385]
# Epoch 1/100
# 14/14 [==============================] - 5s 102ms/step - loss: 0.6146 - masked_acc: 0.6909 - masked_auc: 0.5373 - val_loss: 0.5280 - val_masked_acc: 0.7392 - val_masked_auc: 0.6355
# Epoch 2/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.4344 - masked_acc: 0.7473 - masked_auc: 0.6828 - val_loss: 0.5273 - val_masked_acc: 0.7635 - val_masked_auc: 0.7470
# Epoch 3/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.3385 - masked_acc: 0.7728 - masked_auc: 0.7710 - val_loss: 0.6286 - val_masked_acc: 0.7858 - val_masked_auc: 0.8029
# Epoch 4/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2901 - masked_acc: 0.7923 - masked_auc: 0.8163 - val_loss: 0.7418 - val_masked_acc: 0.8025 - val_masked_auc: 0.8355
# Epoch 5/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2358 - masked_acc: 0.8083 - masked_auc: 0.8447 - val_loss: 0.8172 - val_masked_acc: 0.8163 - val_masked_auc: 0.8579
# Epoch 6/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2234 - masked_acc: 0.8203 - masked_auc: 0.8639 - val_loss: 1.0563 - val_masked_acc: 0.8270 - val_masked_auc: 0.8724
# Epoch 7/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1970 - masked_acc: 0.8307 - masked_auc: 0.8771 - val_loss: 1.1940 - val_masked_acc: 0.8367 - val_masked_auc: 0.8838
# Epoch 8/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1660 - masked_acc: 0.8399 - masked_auc: 0.8876 - val_loss: 1.3413 - val_masked_acc: 0.8453 - val_masked_auc: 0.8930
# Epoch 9/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1427 - masked_acc: 0.8481 - masked_auc: 0.8963 - val_loss: 1.4200 - val_masked_acc: 0.8524 - val_masked_auc: 0.9004
# Epoch 10/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1375 - masked_acc: 0.8548 - masked_auc: 0.9031 - val_loss: 1.5805 - val_masked_acc: 0.8584 - val_masked_auc: 0.9066
# Epoch 11/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1380 - masked_acc: 0.8604 - masked_auc: 0.9087 - val_loss: 1.6640 - val_masked_acc: 0.8636 - val_masked_auc: 0.9113
# Epoch 12/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1238 - masked_acc: 0.8655 - masked_auc: 0.9131 - val_loss: 1.6807 - val_masked_acc: 0.8684 - val_masked_auc: 0.9155
# 28/28 [==============================] - 0s 6ms/step - loss: 0.1040 - masked_acc: 0.8715 - masked_auc: 0.9188
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4849 - masked_acc: 0.8731 - masked_auc: 0.9201
# Test:  [1.4849257469177246, 0.8731179237365723, 0.920065701007843]
# Epoch 1/100
# 14/14 [==============================] - 5s 104ms/step - loss: 0.5721 - masked_acc: 0.7266 - masked_auc: 0.5745 - val_loss: 0.4699 - val_masked_acc: 0.7486 - val_masked_auc: 0.6984
# Epoch 2/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.4259 - masked_acc: 0.7574 - masked_auc: 0.7348 - val_loss: 0.4915 - val_masked_acc: 0.7723 - val_masked_auc: 0.7800
# Epoch 3/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.3370 - masked_acc: 0.7809 - masked_auc: 0.7992 - val_loss: 0.5602 - val_masked_acc: 0.7939 - val_masked_auc: 0.8243
# Epoch 4/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2752 - masked_acc: 0.8007 - masked_auc: 0.8362 - val_loss: 0.7102 - val_masked_acc: 0.8116 - val_masked_auc: 0.8528
# Epoch 5/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2328 - masked_acc: 0.8167 - masked_auc: 0.8606 - val_loss: 0.8444 - val_masked_acc: 0.8252 - val_masked_auc: 0.8721
# Epoch 6/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1965 - masked_acc: 0.8295 - masked_auc: 0.8778 - val_loss: 0.9126 - val_masked_acc: 0.8366 - val_masked_auc: 0.8866
# Epoch 7/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1715 - masked_acc: 0.8401 - masked_auc: 0.8911 - val_loss: 1.0122 - val_masked_acc: 0.8458 - val_masked_auc: 0.8976
# Epoch 8/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1666 - masked_acc: 0.8484 - masked_auc: 0.9008 - val_loss: 1.0461 - val_masked_acc: 0.8530 - val_masked_auc: 0.9056
# Epoch 9/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1480 - masked_acc: 0.8555 - masked_auc: 0.9084 - val_loss: 1.1839 - val_masked_acc: 0.8589 - val_masked_auc: 0.9120
# Epoch 10/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.1377 - masked_acc: 0.8610 - masked_auc: 0.9143 - val_loss: 1.2846 - val_masked_acc: 0.8641 - val_masked_auc: 0.9174
# Epoch 11/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.1230 - masked_acc: 0.8661 - masked_auc: 0.9194 - val_loss: 1.3133 - val_masked_acc: 0.8694 - val_masked_auc: 0.9221
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1012 - masked_acc: 0.8727 - masked_auc: 0.9256
# 4/4 [==============================] - 0s 8ms/step - loss: 1.1594 - masked_acc: 0.8747 - masked_auc: 0.9272
# Test:  [1.159403920173645, 0.8747488260269165, 0.9272222518920898]
# Epoch 1/100
# 14/14 [==============================] - 6s 101ms/step - loss: 0.5843 - masked_acc: 0.6334 - masked_auc: 0.5578 - val_loss: 0.5249 - val_masked_acc: 0.7315 - val_masked_auc: 0.6665
# Epoch 2/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.4232 - masked_acc: 0.7424 - masked_auc: 0.7075 - val_loss: 0.5617 - val_masked_acc: 0.7609 - val_masked_auc: 0.7604
# Epoch 3/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.3344 - masked_acc: 0.7707 - masked_auc: 0.7816 - val_loss: 0.5909 - val_masked_acc: 0.7844 - val_masked_auc: 0.8087
# Epoch 4/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2856 - masked_acc: 0.7918 - masked_auc: 0.8210 - val_loss: 0.7914 - val_masked_acc: 0.8032 - val_masked_auc: 0.8387
# Epoch 5/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2376 - masked_acc: 0.8092 - masked_auc: 0.8479 - val_loss: 0.8727 - val_masked_acc: 0.8182 - val_masked_auc: 0.8602
# Epoch 6/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2048 - masked_acc: 0.8229 - masked_auc: 0.8665 - val_loss: 0.9036 - val_masked_acc: 0.8296 - val_masked_auc: 0.8752
# Epoch 7/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1829 - masked_acc: 0.8333 - masked_auc: 0.8803 - val_loss: 1.1104 - val_masked_acc: 0.8392 - val_masked_auc: 0.8866
# Epoch 8/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1607 - masked_acc: 0.8422 - masked_auc: 0.8904 - val_loss: 1.2483 - val_masked_acc: 0.8472 - val_masked_auc: 0.8956
# Epoch 9/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1468 - masked_acc: 0.8500 - masked_auc: 0.8988 - val_loss: 1.2983 - val_masked_acc: 0.8544 - val_masked_auc: 0.9031
# Epoch 10/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.1265 - masked_acc: 0.8569 - masked_auc: 0.9059 - val_loss: 1.5049 - val_masked_acc: 0.8607 - val_masked_auc: 0.9090
# Epoch 11/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1268 - masked_acc: 0.8627 - masked_auc: 0.9111 - val_loss: 1.5786 - val_masked_acc: 0.8660 - val_masked_auc: 0.9136
# 28/28 [==============================] - 0s 6ms/step - loss: 0.1023 - masked_acc: 0.8694 - masked_auc: 0.9174
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3665 - masked_acc: 0.8714 - masked_auc: 0.9190
# Test:  [1.3665494918823242, 0.87143874168396, 0.9189687967300415]
# Epoch 1/100
# 14/14 [==============================] - 5s 100ms/step - loss: 0.6014 - masked_acc: 0.6368 - masked_auc: 0.5403 - val_loss: 0.5030 - val_masked_acc: 0.7288 - val_masked_auc: 0.6595
# Epoch 2/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.4243 - masked_acc: 0.7439 - masked_auc: 0.7033 - val_loss: 0.5648 - val_masked_acc: 0.7589 - val_masked_auc: 0.7575
# Epoch 3/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.3536 - masked_acc: 0.7677 - masked_auc: 0.7766 - val_loss: 0.6455 - val_masked_acc: 0.7819 - val_masked_auc: 0.8068
# Epoch 4/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.2801 - masked_acc: 0.7894 - masked_auc: 0.8206 - val_loss: 0.7348 - val_masked_acc: 0.8008 - val_masked_auc: 0.8390
# Epoch 5/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.2384 - masked_acc: 0.8066 - masked_auc: 0.8478 - val_loss: 0.9422 - val_masked_acc: 0.8158 - val_masked_auc: 0.8601
# Epoch 6/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1967 - masked_acc: 0.8210 - masked_auc: 0.8668 - val_loss: 0.9604 - val_masked_acc: 0.8281 - val_masked_auc: 0.8758
# Epoch 7/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1904 - masked_acc: 0.8317 - masked_auc: 0.8804 - val_loss: 1.2119 - val_masked_acc: 0.8379 - val_masked_auc: 0.8873
# Epoch 8/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1685 - masked_acc: 0.8410 - masked_auc: 0.8909 - val_loss: 1.2585 - val_masked_acc: 0.8460 - val_masked_auc: 0.8960
# Epoch 9/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1576 - masked_acc: 0.8487 - masked_auc: 0.8991 - val_loss: 1.3828 - val_masked_acc: 0.8527 - val_masked_auc: 0.9030
# Epoch 10/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1349 - masked_acc: 0.8552 - masked_auc: 0.9058 - val_loss: 1.4328 - val_masked_acc: 0.8589 - val_masked_auc: 0.9090
# Epoch 11/100
# 14/14 [==============================] - 0s 25ms/step - loss: 0.1333 - masked_acc: 0.8610 - masked_auc: 0.9112 - val_loss: 1.6692 - val_masked_acc: 0.8642 - val_masked_auc: 0.9140
# 28/28 [==============================] - 0s 6ms/step - loss: 0.1074 - masked_acc: 0.8676 - masked_auc: 0.9178
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2596 - masked_acc: 0.8697 - masked_auc: 0.9194
# Test:  [1.2595714330673218, 0.8696686029434204, 0.9193856120109558]

# %%
t_eval = np.array(test_eval)
print("test avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("test avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("test avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# test avg loss:  1.3255590915679931 +/- 0.10959032005997338
# test avg acc:  0.8722159028053283 +/- 0.00169317833276123
# test avg auc:  0.9220947980880737 +/- 0.0033169212684915597

# %%
t_eval = np.array(train_eval)
print("train avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("train avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("train avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# train avg loss:  0.10475577116012573 +/- 0.002959543003747366
# train avg acc:  0.8702900171279907 +/- 0.0017420909163153187
# train avg auc:  0.9206137657165527 +/- 0.0033280405553155878
