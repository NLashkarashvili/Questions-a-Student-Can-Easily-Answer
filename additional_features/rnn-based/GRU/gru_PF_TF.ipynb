# %%
import warnings
import tensorflow as tf
from tensorflow import keras
from random import choice
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, GRU, Concatenate, Embedding, Flatten, Activation, Dropout
from sklearn.model_selection import KFold
from tensorflow.python.client import device_lib
warnings.filterwarnings('ignore')
import random

# %%
MAXLENGTH = 13
EMBEDDING_DIM = 128
DENSE_NEURON = 16
GRU_NEURON = 32

# %%
FEATURES_SIZE = 2
CHAPTER_SIZE = 38
SUB_CHAPTER_SIZE = 223
QUESTION_SIZE = 1069

# %%
import torch
X = np.array(grouped_data.keys())
kfold = KFold(n_splits=5, shuffle=True)
train_losses = list()
train_aucs = list()
val_losses = list()
val_aucs = list()
train_eval = list()
test_eval = list()
for train, test in kfold.split(X):
    users_train, users_test =  X[train], X[test]
    n = len(users_test)//2
    users_test, users_val = users_test[:n], users_test[n: ]
    train_data_space = SPACE_DATASET(grouped_data[users_train], MAXLENGTH)
    val_data_space = SPACE_DATASET(grouped_data[users_val], MAXLENGTH)
    test_data_space = SPACE_DATASET(grouped_data[users_test], MAXLENGTH)
    #construct training input
    train_chapter=[]
    train_sub_chapter=[]
    train_question = []
    train_features=[]
    train_shifted_t = []
    train_labels=[]
    for i in range(len(users_train)):
        user = train_data_space.__getitem__(i)
        train_chapter.append(user[0])
        train_sub_chapter.append(user[1]) 
        train_question.append(user[2])
        train_features.append(user[3])
        train_shifted_t.append(user[4])
        train_labels.append(user[5])
    train_chapter = np.array(train_chapter)
    train_sub_chapter = np.array(train_sub_chapter)
    train_question = np.array(train_question)
    train_features = np.array(train_features)
    train_shifted_t = np.array(train_shifted_t)
    train_labels= np.array(train_labels)[..., np.newaxis]

    #construct validation input
    val_chapter=[]
    val_sub_chapter=[]
    val_question = []
    val_features=[]
    val_shifted_t = []
    val_labels=[]
    for i in range(len(users_val)):
        user = val_data_space.__getitem__(i)
        val_chapter.append(user[0])
        val_sub_chapter.append(user[1]) 
        val_question.append(user[2])
        val_features.append(user[3])
        val_shifted_t.append(user[4])
        val_labels.append(user[5])
    val_chapter = np.array(val_chapter)
    val_sub_chapter = np.array(val_sub_chapter)
    val_features = np.array(val_features)
    val_question = np.array(val_question)
    val_shifted_t = np.array(val_shifted_t)
    val_labels= np.array(val_labels)[..., np.newaxis]

    # construct test input
    test_chapter=[]
    test_sub_chapter=[]
    test_features=[]
    test_question=[]
    test_shifted_t = []
    test_labels=[]
    for i in range(len(users_test)):
        user = test_data_space.__getitem__(i)
        test_chapter.append(user[0])
        test_sub_chapter.append(user[1]) 
        test_question.append(user[2])
        test_features.append(user[3])
        test_shifted_t.append(user[4])
        test_labels.append(user[5])
    test_chapter = np.array(test_chapter)
    test_sub_chapter = np.array(test_sub_chapter)
    test_features = np.array(test_features)
    test_question = np.array(test_question)
    test_shifted_t = np.array(test_shifted_t)
    test_labels= np.array(test_labels)[..., np.newaxis]

    # define loss function and evaluation metrics
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    acc = tf.keras.metrics.Accuracy()
    auc = tf.keras.metrics.AUC()

    def masked_bce(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return bce(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_acc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      flat_pred = (flat_pred >= 0.5)
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return acc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_auc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return auc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    # input layer
    input_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_sub_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_ques =  tf.keras.Input(shape=(MAXLENGTH))
    input_shifted = tf.keras.Input(shape=(MAXLENGTH))
    input_features = tf.keras.Input(shape=(MAXLENGTH, FEATURES_SIZE))

    # embedding layer for categorical features
    embedding_chap = Embedding(input_dim = CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_chap)
    embedding_sub_chap = Embedding(input_dim = SUB_CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_sub_chap) 
    embedding_ques = Embedding(input_dim = QUESTION_SIZE, output_dim = EMBEDDING_DIM)(input_ques)       
    embedding_shifted = Embedding(input_dim = 3, output_dim = EMBEDDING_DIM)(input_shifted)
    # dense layer for numeric features
    dense_features = Dense(EMBEDDING_DIM,input_shape = (None, MAXLENGTH))(input_features)

    # definr gru layers
    gru_chap = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_chap)
    gru_sub_chap = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_sub_chap)
    gru_ques = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_ques)
    gru_shif = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_shifted)
    gru_features = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(dense_features)

    gru_output = tf.concat([gru_chap, gru_sub_chap, gru_ques, gru_shif, gru_features], axis = 2)

    dense1 = Dense(256, input_shape = (None, 5*EMBEDDING_DIM), activation='relu')(gru_output)
    dropout1 = Dropout(0.1)(dense1)
    dense2 = Dense(64, input_shape = (None, 256), activation='relu')(dropout1)
    dropout2 = Dropout(0.1)(dense2)
    pred = Dense(1, input_shape = (None, 64), activation='sigmoid')(dropout2)

    model = tf.keras.Model(
        inputs=[input_chap, input_sub_chap,input_ques, input_shifted, input_features],
        outputs=pred,
        name='gru_model'
    )

    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt_adam = Adam(learning_rate = 0.005)
    model.compile(
        optimizer=opt_adam,
        loss= masked_bce,
        metrics = [masked_acc, masked_auc]
    )

    history = model.fit(
      [train_chapter, train_sub_chapter, train_question, train_shifted_t, train_features],
      train_labels,
      batch_size = 64,
      epochs = 100,
      validation_data=([val_chapter, val_sub_chapter, val_question, val_shifted_t, val_features], val_labels),
      callbacks=[callback]
    )
    val_losses.append(list(history.history['val_loss']))
    train_losses.append(list(history.history['loss']))
    val_aucs.append(list(history.history['val_masked_auc']))
    train_aucs.append(list(history.history['masked_auc']))
    train_score = model.evaluate([train_chapter, train_sub_chapter, train_question, train_shifted_t, train_features], train_labels)
    train_eval.append(train_score)
    test_score = model.evaluate([test_chapter, test_sub_chapter, test_question, test_shifted_t, test_features], test_labels)
    test_eval.append(test_score)
    print("Test: ", test_score)
    def reset_weights(model):
      for layer in model.layers: 
        if isinstance(layer, tf.keras.Model):
          reset_weights(layer)
          continue
        for k, initializer in layer.__dict__.items():
          if "initializer" not in k:
            continue
          # find the corresponding variable
          var = getattr(layer, k.replace("_initializer", ""))
          var.assign(initializer(var.shape, var.dtype))
    reset_weights(model)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 12s 225ms/step - loss: 0.5958 - masked_acc: 0.5659 - masked_auc: 0.5414 - val_loss: 0.5037 - val_masked_acc: 0.7151 - val_masked_auc: 0.6665
# Epoch 2/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.4542 - masked_acc: 0.7279 - masked_auc: 0.7031 - val_loss: 0.5087 - val_masked_acc: 0.7454 - val_masked_auc: 0.7480
# Epoch 3/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4206 - masked_acc: 0.7513 - masked_auc: 0.7611 - val_loss: 0.4968 - val_masked_acc: 0.7616 - val_masked_auc: 0.7814
# Epoch 4/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3935 - masked_acc: 0.7653 - masked_auc: 0.7885 - val_loss: 0.5354 - val_masked_acc: 0.7708 - val_masked_auc: 0.8002
# Epoch 5/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3743 - masked_acc: 0.7736 - masked_auc: 0.8061 - val_loss: 0.5866 - val_masked_acc: 0.7784 - val_masked_auc: 0.8142
# Epoch 6/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.3542 - masked_acc: 0.7808 - masked_auc: 0.8190 - val_loss: 0.6270 - val_masked_acc: 0.7842 - val_masked_auc: 0.8252
# Epoch 7/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3232 - masked_acc: 0.7869 - masked_auc: 0.8296 - val_loss: 0.6480 - val_masked_acc: 0.7903 - val_masked_auc: 0.8351
# Epoch 8/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3295 - masked_acc: 0.7921 - masked_auc: 0.8382 - val_loss: 0.7493 - val_masked_acc: 0.7956 - val_masked_auc: 0.8433
# Epoch 9/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3126 - masked_acc: 0.7974 - masked_auc: 0.8460 - val_loss: 0.7916 - val_masked_acc: 0.8004 - val_masked_auc: 0.8502
# Epoch 10/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2711 - masked_acc: 0.8024 - masked_auc: 0.8532 - val_loss: 0.9377 - val_masked_acc: 0.8053 - val_masked_auc: 0.8570
# Epoch 11/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2491 - masked_acc: 0.8074 - masked_auc: 0.8599 - val_loss: 0.9501 - val_masked_acc: 0.8098 - val_masked_auc: 0.8630
# Epoch 12/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2439 - masked_acc: 0.8116 - masked_auc: 0.8656 - val_loss: 0.9881 - val_masked_acc: 0.8141 - val_masked_auc: 0.8685
# Epoch 13/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2427 - masked_acc: 0.8155 - masked_auc: 0.8705 - val_loss: 1.2369 - val_masked_acc: 0.8179 - val_masked_auc: 0.8731
# 28/28 [==============================] - 0s 7ms/step - loss: 0.2107 - masked_acc: 0.8206 - masked_auc: 0.8769
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7810 - masked_acc: 0.8227 - masked_auc: 0.8793
# Test:  [0.7809767127037048, 0.8227059245109558, 0.8793305158615112]
# Epoch 1/100
# 14/14 [==============================] - 12s 209ms/step - loss: 0.5914 - masked_acc: 0.7282 - masked_auc: 0.5235 - val_loss: 0.4836 - val_masked_acc: 0.7386 - val_masked_auc: 0.6648
# Epoch 2/100
# 14/14 [==============================] - 1s 46ms/step - loss: 0.4582 - masked_acc: 0.7441 - masked_auc: 0.6995 - val_loss: 0.4684 - val_masked_acc: 0.7585 - val_masked_auc: 0.7492
# Epoch 3/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4135 - masked_acc: 0.7630 - masked_auc: 0.7630 - val_loss: 0.4913 - val_masked_acc: 0.7692 - val_masked_auc: 0.7816
# Epoch 4/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3986 - masked_acc: 0.7718 - masked_auc: 0.7890 - val_loss: 0.5070 - val_masked_acc: 0.7768 - val_masked_auc: 0.8007
# Epoch 5/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3714 - masked_acc: 0.7794 - masked_auc: 0.8063 - val_loss: 0.5304 - val_masked_acc: 0.7830 - val_masked_auc: 0.8140
# Epoch 6/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3447 - masked_acc: 0.7857 - masked_auc: 0.8188 - val_loss: 0.5945 - val_masked_acc: 0.7890 - val_masked_auc: 0.8247
# Epoch 7/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3448 - masked_acc: 0.7908 - masked_auc: 0.8281 - val_loss: 0.6068 - val_masked_acc: 0.7942 - val_masked_auc: 0.8339
# Epoch 8/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3083 - masked_acc: 0.7964 - masked_auc: 0.8373 - val_loss: 0.7542 - val_masked_acc: 0.7990 - val_masked_auc: 0.8419
# Epoch 9/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3096 - masked_acc: 0.8006 - masked_auc: 0.8446 - val_loss: 0.7689 - val_masked_acc: 0.8032 - val_masked_auc: 0.8487
# Epoch 10/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.2808 - masked_acc: 0.8050 - masked_auc: 0.8513 - val_loss: 0.8826 - val_masked_acc: 0.8076 - val_masked_auc: 0.8552
# Epoch 11/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2661 - masked_acc: 0.8093 - masked_auc: 0.8578 - val_loss: 1.0242 - val_masked_acc: 0.8121 - val_masked_auc: 0.8616
# Epoch 12/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2570 - masked_acc: 0.8136 - masked_auc: 0.8638 - val_loss: 0.9794 - val_masked_acc: 0.8161 - val_masked_auc: 0.8672
# 28/28 [==============================] - 0s 7ms/step - loss: 0.2270 - masked_acc: 0.8190 - masked_auc: 0.8714
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8507 - masked_acc: 0.8208 - masked_auc: 0.8737
# Test:  [0.8506640195846558, 0.820778489112854, 0.873650074005127]
# Epoch 1/100
# 14/14 [==============================] - 12s 191ms/step - loss: 0.5891 - masked_acc: 0.6458 - masked_auc: 0.5603 - val_loss: 0.4999 - val_masked_acc: 0.7336 - val_masked_auc: 0.6777
# Epoch 2/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.4369 - masked_acc: 0.7437 - masked_auc: 0.7152 - val_loss: 0.4635 - val_masked_acc: 0.7597 - val_masked_auc: 0.7586
# Epoch 3/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.4065 - masked_acc: 0.7645 - masked_auc: 0.7703 - val_loss: 0.4790 - val_masked_acc: 0.7731 - val_masked_auc: 0.7904
# Epoch 4/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3894 - masked_acc: 0.7756 - masked_auc: 0.7977 - val_loss: 0.4995 - val_masked_acc: 0.7819 - val_masked_auc: 0.8091
# Epoch 5/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3576 - masked_acc: 0.7846 - masked_auc: 0.8146 - val_loss: 0.5152 - val_masked_acc: 0.7890 - val_masked_auc: 0.8223
# Epoch 6/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3411 - masked_acc: 0.7914 - masked_auc: 0.8266 - val_loss: 0.5417 - val_masked_acc: 0.7952 - val_masked_auc: 0.8331
# Epoch 7/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3197 - masked_acc: 0.7973 - masked_auc: 0.8367 - val_loss: 0.5952 - val_masked_acc: 0.8007 - val_masked_auc: 0.8422
# Epoch 8/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3159 - masked_acc: 0.8026 - masked_auc: 0.8453 - val_loss: 0.6348 - val_masked_acc: 0.8064 - val_masked_auc: 0.8504
# Epoch 9/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2870 - masked_acc: 0.8083 - masked_auc: 0.8533 - val_loss: 0.6952 - val_masked_acc: 0.8119 - val_masked_auc: 0.8577
# Epoch 10/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2739 - masked_acc: 0.8135 - masked_auc: 0.8602 - val_loss: 0.7586 - val_masked_acc: 0.8166 - val_masked_auc: 0.8642
# Epoch 11/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2544 - masked_acc: 0.8182 - masked_auc: 0.8665 - val_loss: 0.7967 - val_masked_acc: 0.8210 - val_masked_auc: 0.8701
# Epoch 12/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2309 - masked_acc: 0.8227 - masked_auc: 0.8723 - val_loss: 0.9647 - val_masked_acc: 0.8254 - val_masked_auc: 0.8755
# 28/28 [==============================] - 0s 7ms/step - loss: 0.2119 - masked_acc: 0.8282 - masked_auc: 0.8794
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9755 - masked_acc: 0.8299 - masked_auc: 0.8816
# Test:  [0.9755083322525024, 0.8299330472946167, 0.8815772533416748]
# Epoch 1/100
# 14/14 [==============================] - 12s 205ms/step - loss: 0.5958 - masked_acc: 0.6091 - masked_auc: 0.5584 - val_loss: 0.4897 - val_masked_acc: 0.7243 - val_masked_auc: 0.6557
# Epoch 2/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4602 - masked_acc: 0.7343 - masked_auc: 0.6917 - val_loss: 0.4580 - val_masked_acc: 0.7510 - val_masked_auc: 0.7417
# Epoch 3/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4103 - masked_acc: 0.7577 - masked_auc: 0.7560 - val_loss: 0.4533 - val_masked_acc: 0.7653 - val_masked_auc: 0.7766
# Epoch 4/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3995 - masked_acc: 0.7688 - masked_auc: 0.7836 - val_loss: 0.4664 - val_masked_acc: 0.7749 - val_masked_auc: 0.7967
# Epoch 5/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3785 - masked_acc: 0.7770 - masked_auc: 0.8019 - val_loss: 0.4935 - val_masked_acc: 0.7812 - val_masked_auc: 0.8103
# Epoch 6/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3656 - masked_acc: 0.7832 - masked_auc: 0.8144 - val_loss: 0.5382 - val_masked_acc: 0.7869 - val_masked_auc: 0.8212
# Epoch 7/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3416 - masked_acc: 0.7891 - masked_auc: 0.8251 - val_loss: 0.5858 - val_masked_acc: 0.7921 - val_masked_auc: 0.8303
# Epoch 8/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3225 - masked_acc: 0.7940 - masked_auc: 0.8337 - val_loss: 0.6244 - val_masked_acc: 0.7974 - val_masked_auc: 0.8390
# Epoch 9/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3076 - masked_acc: 0.7991 - masked_auc: 0.8418 - val_loss: 0.7334 - val_masked_acc: 0.8018 - val_masked_auc: 0.8464
# Epoch 10/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2713 - masked_acc: 0.8037 - masked_auc: 0.8494 - val_loss: 0.8090 - val_masked_acc: 0.8061 - val_masked_auc: 0.8533
# Epoch 11/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2569 - masked_acc: 0.8079 - masked_auc: 0.8559 - val_loss: 0.9384 - val_masked_acc: 0.8104 - val_masked_auc: 0.8598
# Epoch 12/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2489 - masked_acc: 0.8121 - masked_auc: 0.8621 - val_loss: 0.9290 - val_masked_acc: 0.8149 - val_masked_auc: 0.8660
# Epoch 13/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2414 - masked_acc: 0.8164 - masked_auc: 0.8681 - val_loss: 1.0461 - val_masked_acc: 0.8188 - val_masked_auc: 0.8713
# 28/28 [==============================] - 0s 7ms/step - loss: 0.2203 - masked_acc: 0.8215 - masked_auc: 0.8751
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8190 - masked_acc: 0.8231 - masked_auc: 0.8771
# Test:  [0.8189899921417236, 0.8230645060539246, 0.8770594596862793]
# Epoch 1/100
# 14/14 [==============================] - 11s 188ms/step - loss: 0.5818 - masked_acc: 0.7138 - masked_auc: 0.5747 - val_loss: 0.4973 - val_masked_acc: 0.7517 - val_masked_auc: 0.6954
# Epoch 2/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4493 - masked_acc: 0.7563 - masked_auc: 0.7233 - val_loss: 0.4842 - val_masked_acc: 0.7683 - val_masked_auc: 0.7635
# Epoch 3/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4094 - masked_acc: 0.7719 - masked_auc: 0.7744 - val_loss: 0.4922 - val_masked_acc: 0.7770 - val_masked_auc: 0.7908
# Epoch 4/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.3863 - masked_acc: 0.7799 - masked_auc: 0.7979 - val_loss: 0.5017 - val_masked_acc: 0.7839 - val_masked_auc: 0.8084
# Epoch 5/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3620 - masked_acc: 0.7866 - masked_auc: 0.8143 - val_loss: 0.5192 - val_masked_acc: 0.7906 - val_masked_auc: 0.8218
# Epoch 6/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3480 - masked_acc: 0.7926 - masked_auc: 0.8258 - val_loss: 0.5812 - val_masked_acc: 0.7956 - val_masked_auc: 0.8324
# Epoch 7/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3309 - masked_acc: 0.7974 - masked_auc: 0.8356 - val_loss: 0.5866 - val_masked_acc: 0.7999 - val_masked_auc: 0.8409
# Epoch 8/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3065 - masked_acc: 0.8018 - masked_auc: 0.8440 - val_loss: 0.6768 - val_masked_acc: 0.8044 - val_masked_auc: 0.8486
# Epoch 9/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2889 - masked_acc: 0.8060 - masked_auc: 0.8514 - val_loss: 0.7373 - val_masked_acc: 0.8089 - val_masked_auc: 0.8559
# Epoch 10/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2865 - masked_acc: 0.8104 - masked_auc: 0.8580 - val_loss: 0.7860 - val_masked_acc: 0.8132 - val_masked_auc: 0.8620
# Epoch 11/100
# 14/14 [==============================] - 1s 49ms/step - loss: 0.2661 - masked_acc: 0.8145 - masked_auc: 0.8641 - val_loss: 0.8971 - val_masked_acc: 0.8174 - val_masked_auc: 0.8679
# Epoch 12/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.2393 - masked_acc: 0.8189 - masked_auc: 0.8701 - val_loss: 0.9894 - val_masked_acc: 0.8217 - val_masked_auc: 0.8737
# 28/28 [==============================] - 0s 8ms/step - loss: 0.2168 - masked_acc: 0.8244 - masked_auc: 0.8775
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8948 - masked_acc: 0.8260 - masked_auc: 0.8796
# Test:  [0.8947798013687134, 0.8260352611541748, 0.8795676827430725]

# %%
t_eval = np.array(test_eval)
print("test avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("test avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("test avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# test avg loss:  0.86418377161026 +/- 0.06704916239377186
# test avg acc:  0.8245034456253052 +/- 0.0031938679799937203
# test avg auc:  0.878236997127533 +/- 0.0027037114180879446

# %%
t_eval = np.array(train_eval)
print("train avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("train avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("train avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# train avg loss:  0.21733868420124053 +/- 0.005934251139738811
# train avg acc:  0.822741174697876 +/- 0.0032402271213683954
# train avg auc:  0.8760464906692504 +/- 0.002724728476374346
