# %%
import warnings
import gc
import tensorflow as tf
from tensorflow import keras
from random import choice
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, GRU, Concatenate, Embedding, Flatten, Activation, Dropout
from sklearn.model_selection import KFold
from tensorflow.python.client import device_lib
warnings.filterwarnings('ignore')
import random

# %%
MAXLENGTH = 13
EMBEDDING_DIM = 128
DENSE_NEURON = 16
GRU_NEURON = 32

# %%
FEATURES_SIZE = 39
CHAPTER_SIZE = 38
SUB_CHAPTER_SIZE = 223
QUESTION_SIZE = 1069

# %%
import torch
X = np.array(grouped_data.keys())
kfold = KFold(n_splits=5, shuffle=True)
train_losses = list()
train_aucs = list()
val_losses = list()
val_aucs = list()
train_eval = list()
test_eval = list()
for train, test in kfold.split(X):
    users_train, users_test =  X[train], X[test]
    n = len(users_test)//2
    users_test, users_val = users_test[:n], users_test[n: ]
    train_data_space = SPACE_DATASET(grouped_data[users_train], MAXLENGTH)
    val_data_space = SPACE_DATASET(grouped_data[users_val], MAXLENGTH)
    test_data_space = SPACE_DATASET(grouped_data[users_test], MAXLENGTH)
    #construct training input
    train_chapter=[]
    train_sub_chapter=[]
    train_question = []
    train_features=[]
    train_shifted_t = []
    train_labels=[]
    for i in range(len(users_train)):
        user = train_data_space.__getitem__(i)
        train_chapter.append(user[0])
        train_sub_chapter.append(user[1]) 
        train_question.append(user[2])
        train_features.append(user[3])
        train_shifted_t.append(user[4])
        train_labels.append(user[5])
    train_chapter = np.array(train_chapter)
    train_sub_chapter = np.array(train_sub_chapter)
    train_question = np.array(train_question)
    train_features = np.array(train_features)
    train_shifted_t = np.array(train_shifted_t)
    train_labels= np.array(train_labels)[..., np.newaxis]

    #construct validation input
    val_chapter=[]
    val_sub_chapter=[]
    val_question = []
    val_features=[]
    val_shifted_t = []
    val_labels=[]
    for i in range(len(users_val)):
        user = val_data_space.__getitem__(i)
        val_chapter.append(user[0])
        val_sub_chapter.append(user[1]) 
        val_question.append(user[2])
        val_features.append(user[3])
        val_shifted_t.append(user[4])
        val_labels.append(user[5])
    val_chapter = np.array(val_chapter)
    val_sub_chapter = np.array(val_sub_chapter)
    val_features = np.array(val_features)
    val_question = np.array(val_question)
    val_shifted_t = np.array(val_shifted_t)
    val_labels= np.array(val_labels)[..., np.newaxis]

    # construct test input
    test_chapter=[]
    test_sub_chapter=[]
    test_features=[]
    test_question=[]
    test_shifted_t = []
    test_labels=[]
    for i in range(len(users_test)):
        user = test_data_space.__getitem__(i)
        test_chapter.append(user[0])
        test_sub_chapter.append(user[1]) 
        test_question.append(user[2])
        test_features.append(user[3])
        test_shifted_t.append(user[4])
        test_labels.append(user[5])
    test_chapter = np.array(test_chapter)
    test_sub_chapter = np.array(test_sub_chapter)
    test_features = np.array(test_features)
    test_question = np.array(test_question)
    test_shifted_t = np.array(test_shifted_t)
    test_labels= np.array(test_labels)[..., np.newaxis]

    # define loss function and evaluation metrics
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    acc = tf.keras.metrics.Accuracy()
    auc = tf.keras.metrics.AUC()

    def masked_bce(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return bce(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_acc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      flat_pred = (flat_pred >= 0.5)
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return acc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_auc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return auc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    # input layer
    input_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_sub_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_ques =  tf.keras.Input(shape=(MAXLENGTH))
    input_shifted = tf.keras.Input(shape=(MAXLENGTH))
    input_features = tf.keras.Input(shape=(MAXLENGTH, FEATURES_SIZE))

    # embedding layer for categorical features
    embedding_chap = Embedding(input_dim = CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_chap)
    embedding_sub_chap = Embedding(input_dim = SUB_CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_sub_chap) 
    embedding_ques = Embedding(input_dim = QUESTION_SIZE, output_dim = EMBEDDING_DIM)(input_ques)       
    embedding_shifted = Embedding(input_dim = 3, output_dim = EMBEDDING_DIM)(input_shifted)
    # dense layer for numeric features
    dense_features = Dense(EMBEDDING_DIM,input_shape = (None, MAXLENGTH))(input_features)

    # definr gru layers
    gru_chap = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_chap)
    gru_sub_chap = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_sub_chap)
    gru_ques = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_ques)
    gru_shif = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_shifted)
    gru_features = GRU(GRU_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(dense_features)

    gru_output = tf.concat([gru_chap, gru_sub_chap, gru_ques, gru_shif, gru_features], axis = 2)

    dense1 = Dense(256, input_shape = (None, 5*EMBEDDING_DIM), activation='relu')(gru_output)
    dropout1 = Dropout(0.1)(dense1)
    dense2 = Dense(64, input_shape = (None, 256), activation='relu')(dropout1)
    dropout2 = Dropout(0.1)(dense2)
    pred = Dense(1, input_shape = (None, 64), activation='sigmoid')(dropout2)

    model = tf.keras.Model(
        inputs=[input_chap, input_sub_chap,input_ques, input_shifted, input_features],
        outputs=pred,
        name='gru_model'
    )

    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt_adam = Adam(learning_rate = 0.005)
    model.compile(
        optimizer=opt_adam,
        loss= masked_bce,
        metrics = [masked_acc, masked_auc]
    )

    history = model.fit(
      [train_chapter, train_sub_chapter, train_question, train_shifted_t, train_features],
      train_labels,
      batch_size = 64,
      epochs = 100,
      validation_data=([val_chapter, val_sub_chapter, val_question, val_shifted_t, val_features], val_labels),
      callbacks=[callback]
    )
    val_losses.append(list(history.history['val_loss']))
    train_losses.append(list(history.history['loss']))
    val_aucs.append(list(history.history['val_masked_auc']))
    train_aucs.append(list(history.history['masked_auc']))
    train_score = model.evaluate([train_chapter, train_sub_chapter, train_question, train_shifted_t, train_features], train_labels)
    train_eval.append(train_score)
    test_score = model.evaluate([test_chapter, test_sub_chapter, test_question, test_shifted_t, test_features], test_labels)
    test_eval.append(test_score)
    print("Test: ", test_score)
    def reset_weights(model):
      for layer in model.layers: 
        if isinstance(layer, tf.keras.Model):
          reset_weights(layer)
          continue
        for k, initializer in layer.__dict__.items():
          if "initializer" not in k:
            continue
          # find the corresponding variable
          var = getattr(layer, k.replace("_initializer", ""))
          var.assign(initializer(var.shape, var.dtype))
    reset_weights(model)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 12s 231ms/step - loss: 0.5921 - masked_acc: 0.6480 - masked_auc: 0.5317 - val_loss: 0.4799 - val_masked_acc: 0.7295 - val_masked_auc: 0.6632
# Epoch 2/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4666 - masked_acc: 0.7368 - masked_auc: 0.6971 - val_loss: 0.4462 - val_masked_acc: 0.7524 - val_masked_auc: 0.7446
# Epoch 3/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4163 - masked_acc: 0.7573 - masked_auc: 0.7584 - val_loss: 0.4563 - val_masked_acc: 0.7655 - val_masked_auc: 0.7800
# Epoch 4/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3913 - masked_acc: 0.7690 - masked_auc: 0.7883 - val_loss: 0.4728 - val_masked_acc: 0.7746 - val_masked_auc: 0.8010
# Epoch 5/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3704 - masked_acc: 0.7775 - masked_auc: 0.8069 - val_loss: 0.4958 - val_masked_acc: 0.7822 - val_masked_auc: 0.8163
# Epoch 6/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.3514 - masked_acc: 0.7847 - masked_auc: 0.8214 - val_loss: 0.5447 - val_masked_acc: 0.7888 - val_masked_auc: 0.8281
# Epoch 7/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3347 - masked_acc: 0.7908 - masked_auc: 0.8318 - val_loss: 0.5714 - val_masked_acc: 0.7945 - val_masked_auc: 0.8380
# Epoch 8/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3124 - masked_acc: 0.7965 - masked_auc: 0.8414 - val_loss: 0.6837 - val_masked_acc: 0.8000 - val_masked_auc: 0.8465
# Epoch 9/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2945 - masked_acc: 0.8018 - masked_auc: 0.8497 - val_loss: 0.7329 - val_masked_acc: 0.8055 - val_masked_auc: 0.8547
# Epoch 10/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2680 - masked_acc: 0.8073 - masked_auc: 0.8575 - val_loss: 0.7905 - val_masked_acc: 0.8105 - val_masked_auc: 0.8618
# Epoch 11/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.2518 - masked_acc: 0.8123 - masked_auc: 0.8644 - val_loss: 0.8374 - val_masked_acc: 0.8153 - val_masked_auc: 0.8682
# Epoch 12/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2419 - masked_acc: 0.8170 - masked_auc: 0.8705 - val_loss: 0.8773 - val_masked_acc: 0.8199 - val_masked_auc: 0.8741
# 28/28 [==============================] - 0s 8ms/step - loss: 0.2200 - masked_acc: 0.8229 - masked_auc: 0.8783
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6678 - masked_acc: 0.8248 - masked_auc: 0.8805
# Test:  [0.6677665114402771, 0.8247952461242676, 0.8805125951766968]
# Epoch 1/100
# 14/14 [==============================] - 12s 207ms/step - loss: 0.5854 - masked_acc: 0.7212 - masked_auc: 0.5650 - val_loss: 0.5357 - val_masked_acc: 0.7418 - val_masked_auc: 0.6512
# Epoch 2/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.4550 - masked_acc: 0.7494 - masked_auc: 0.6893 - val_loss: 0.5034 - val_masked_acc: 0.7605 - val_masked_auc: 0.7366
# Epoch 3/100
# 14/14 [==============================] - 1s 46ms/step - loss: 0.4235 - masked_acc: 0.7638 - masked_auc: 0.7525 - val_loss: 0.4921 - val_masked_acc: 0.7716 - val_masked_auc: 0.7746
# Epoch 4/100
# 14/14 [==============================] - 1s 48ms/step - loss: 0.3900 - masked_acc: 0.7746 - masked_auc: 0.7830 - val_loss: 0.5051 - val_masked_acc: 0.7793 - val_masked_auc: 0.7965
# Epoch 5/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.3650 - masked_acc: 0.7819 - masked_auc: 0.8028 - val_loss: 0.5154 - val_masked_acc: 0.7853 - val_masked_auc: 0.8119
# Epoch 6/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3473 - masked_acc: 0.7877 - masked_auc: 0.8171 - val_loss: 0.5470 - val_masked_acc: 0.7905 - val_masked_auc: 0.8238
# Epoch 7/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3409 - masked_acc: 0.7923 - masked_auc: 0.8275 - val_loss: 0.6035 - val_masked_acc: 0.7958 - val_masked_auc: 0.8335
# Epoch 8/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3161 - masked_acc: 0.7977 - masked_auc: 0.8370 - val_loss: 0.6396 - val_masked_acc: 0.8010 - val_masked_auc: 0.8429
# Epoch 9/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2930 - masked_acc: 0.8029 - masked_auc: 0.8461 - val_loss: 0.7581 - val_masked_acc: 0.8067 - val_masked_auc: 0.8518
# Epoch 10/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2642 - masked_acc: 0.8087 - masked_auc: 0.8549 - val_loss: 0.8092 - val_masked_acc: 0.8123 - val_masked_auc: 0.8597
# Epoch 11/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2509 - masked_acc: 0.8142 - masked_auc: 0.8624 - val_loss: 0.8252 - val_masked_acc: 0.8174 - val_masked_auc: 0.8667
# Epoch 12/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2246 - masked_acc: 0.8193 - masked_auc: 0.8694 - val_loss: 0.9339 - val_masked_acc: 0.8226 - val_masked_auc: 0.8734
# Epoch 13/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2010 - masked_acc: 0.8245 - masked_auc: 0.8760 - val_loss: 1.1524 - val_masked_acc: 0.8276 - val_masked_auc: 0.8795
# 28/28 [==============================] - 0s 7ms/step - loss: 0.1790 - masked_acc: 0.8308 - masked_auc: 0.8837
# 4/4 [==============================] - 0s 8ms/step - loss: 1.1167 - masked_acc: 0.8327 - masked_auc: 0.8859
# Test:  [1.1166801452636719, 0.832664966583252, 0.8859227895736694]
# Epoch 1/100
# 14/14 [==============================] - 12s 194ms/step - loss: 0.5835 - masked_acc: 0.6907 - masked_auc: 0.5271 - val_loss: 0.4762 - val_masked_acc: 0.7385 - val_masked_auc: 0.6657
# Epoch 2/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4523 - masked_acc: 0.7465 - masked_auc: 0.6988 - val_loss: 0.4614 - val_masked_acc: 0.7587 - val_masked_auc: 0.7482
# Epoch 3/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4065 - masked_acc: 0.7629 - masked_auc: 0.7624 - val_loss: 0.4708 - val_masked_acc: 0.7715 - val_masked_auc: 0.7843
# Epoch 4/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3844 - masked_acc: 0.7747 - masked_auc: 0.7925 - val_loss: 0.4880 - val_masked_acc: 0.7804 - val_masked_auc: 0.8052
# Epoch 5/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3695 - masked_acc: 0.7828 - masked_auc: 0.8101 - val_loss: 0.4943 - val_masked_acc: 0.7873 - val_masked_auc: 0.8198
# Epoch 6/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.3513 - masked_acc: 0.7897 - masked_auc: 0.8243 - val_loss: 0.5445 - val_masked_acc: 0.7933 - val_masked_auc: 0.8313
# Epoch 7/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3419 - masked_acc: 0.7950 - masked_auc: 0.8347 - val_loss: 0.5658 - val_masked_acc: 0.7991 - val_masked_auc: 0.8409
# Epoch 8/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3063 - masked_acc: 0.8011 - masked_auc: 0.8444 - val_loss: 0.6094 - val_masked_acc: 0.8045 - val_masked_auc: 0.8498
# Epoch 9/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2779 - masked_acc: 0.8066 - masked_auc: 0.8529 - val_loss: 0.6482 - val_masked_acc: 0.8099 - val_masked_auc: 0.8579
# Epoch 10/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2634 - masked_acc: 0.8118 - masked_auc: 0.8607 - val_loss: 0.7325 - val_masked_acc: 0.8149 - val_masked_auc: 0.8650
# Epoch 11/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2489 - masked_acc: 0.8167 - masked_auc: 0.8675 - val_loss: 0.7949 - val_masked_acc: 0.8199 - val_masked_auc: 0.8717
# Epoch 12/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2250 - masked_acc: 0.8216 - masked_auc: 0.8742 - val_loss: 0.8708 - val_masked_acc: 0.8245 - val_masked_auc: 0.8781
# 28/28 [==============================] - 0s 8ms/step - loss: 0.2032 - masked_acc: 0.8277 - masked_auc: 0.8823
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0636 - masked_acc: 0.8294 - masked_auc: 0.8843
# Test:  [1.0636112689971924, 0.8294168710708618, 0.8842734098434448]
# Epoch 1/100
# 14/14 [==============================] - 12s 198ms/step - loss: 0.5861 - masked_acc: 0.6703 - masked_auc: 0.5563 - val_loss: 0.5048 - val_masked_acc: 0.7429 - val_masked_auc: 0.6766
# Epoch 2/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4367 - masked_acc: 0.7525 - masked_auc: 0.7120 - val_loss: 0.4877 - val_masked_acc: 0.7633 - val_masked_auc: 0.7562
# Epoch 3/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4053 - masked_acc: 0.7673 - masked_auc: 0.7691 - val_loss: 0.4826 - val_masked_acc: 0.7744 - val_masked_auc: 0.7897
# Epoch 4/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3822 - masked_acc: 0.7772 - masked_auc: 0.7974 - val_loss: 0.5076 - val_masked_acc: 0.7812 - val_masked_auc: 0.8091
# Epoch 5/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.3510 - masked_acc: 0.7845 - masked_auc: 0.8153 - val_loss: 0.5290 - val_masked_acc: 0.7890 - val_masked_auc: 0.8239
# Epoch 6/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3352 - masked_acc: 0.7913 - masked_auc: 0.8288 - val_loss: 0.5526 - val_masked_acc: 0.7951 - val_masked_auc: 0.8358
# Epoch 7/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3149 - masked_acc: 0.7971 - masked_auc: 0.8398 - val_loss: 0.5756 - val_masked_acc: 0.8004 - val_masked_auc: 0.8453
# Epoch 8/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2967 - masked_acc: 0.8025 - masked_auc: 0.8486 - val_loss: 0.5579 - val_masked_acc: 0.8055 - val_masked_auc: 0.8539
# Epoch 9/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2810 - masked_acc: 0.8074 - masked_auc: 0.8570 - val_loss: 0.6275 - val_masked_acc: 0.8105 - val_masked_auc: 0.8618
# Epoch 10/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.2470 - masked_acc: 0.8126 - masked_auc: 0.8648 - val_loss: 0.6714 - val_masked_acc: 0.8154 - val_masked_auc: 0.8688
# Epoch 11/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2424 - masked_acc: 0.8171 - masked_auc: 0.8713 - val_loss: 0.7562 - val_masked_acc: 0.8199 - val_masked_auc: 0.8753
# Epoch 12/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2205 - masked_acc: 0.8215 - masked_auc: 0.8775 - val_loss: 0.7798 - val_masked_acc: 0.8242 - val_masked_auc: 0.8812
# Epoch 13/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2149 - masked_acc: 0.8257 - masked_auc: 0.8832 - val_loss: 0.9139 - val_masked_acc: 0.8284 - val_masked_auc: 0.8863
# 28/28 [==============================] - 0s 7ms/step - loss: 0.1907 - masked_acc: 0.8312 - masked_auc: 0.8900
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8826 - masked_acc: 0.8328 - masked_auc: 0.8918
# Test:  [0.8825808167457581, 0.832751452922821, 0.8917909860610962]
# Epoch 1/100
# 14/14 [==============================] - 12s 196ms/step - loss: 0.6110 - masked_acc: 0.5320 - masked_auc: 0.5160 - val_loss: 0.5215 - val_masked_acc: 0.7091 - val_masked_auc: 0.6364
# Epoch 2/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.4620 - masked_acc: 0.7219 - masked_auc: 0.6738 - val_loss: 0.5034 - val_masked_acc: 0.7406 - val_masked_auc: 0.7277
# Epoch 3/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4070 - masked_acc: 0.7486 - masked_auc: 0.7452 - val_loss: 0.5015 - val_masked_acc: 0.7580 - val_masked_auc: 0.7681
# Epoch 4/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.4037 - masked_acc: 0.7614 - masked_auc: 0.7767 - val_loss: 0.5373 - val_masked_acc: 0.7687 - val_masked_auc: 0.7899
# Epoch 5/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.3827 - masked_acc: 0.7715 - masked_auc: 0.7959 - val_loss: 0.5499 - val_masked_acc: 0.7766 - val_masked_auc: 0.8055
# Epoch 6/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.3575 - masked_acc: 0.7788 - masked_auc: 0.8105 - val_loss: 0.6055 - val_masked_acc: 0.7834 - val_masked_auc: 0.8186
# Epoch 7/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3421 - masked_acc: 0.7855 - masked_auc: 0.8227 - val_loss: 0.7253 - val_masked_acc: 0.7899 - val_masked_auc: 0.8291
# Epoch 8/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.2985 - masked_acc: 0.7926 - masked_auc: 0.8331 - val_loss: 0.7221 - val_masked_acc: 0.7960 - val_masked_auc: 0.8384
# Epoch 9/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.2936 - masked_acc: 0.7981 - masked_auc: 0.8417 - val_loss: 0.8538 - val_masked_acc: 0.8018 - val_masked_auc: 0.8468
# Epoch 10/100
# 14/14 [==============================] - 1s 50ms/step - loss: 0.2740 - masked_acc: 0.8037 - masked_auc: 0.8499 - val_loss: 0.9994 - val_masked_acc: 0.8072 - val_masked_auc: 0.8544
# Epoch 11/100
# 14/14 [==============================] - 1s 45ms/step - loss: 0.2503 - masked_acc: 0.8091 - masked_auc: 0.8572 - val_loss: 1.1105 - val_masked_acc: 0.8123 - val_masked_auc: 0.8613
# Epoch 12/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.2205 - masked_acc: 0.8143 - masked_auc: 0.8641 - val_loss: 1.1370 - val_masked_acc: 0.8173 - val_masked_auc: 0.8679
# Epoch 13/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2124 - masked_acc: 0.8192 - masked_auc: 0.8704 - val_loss: 1.1764 - val_masked_acc: 0.8222 - val_masked_auc: 0.8737
# 28/28 [==============================] - 0s 8ms/step - loss: 0.1895 - masked_acc: 0.8254 - masked_auc: 0.8779
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7903 - masked_acc: 0.8275 - masked_auc: 0.8807
# Test:  [0.7902637720108032, 0.8275201320648193, 0.8806815147399902]

# %%
t_eval = np.array(test_eval)
print("test avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("test avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("test avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# test avg loss:  0.9041805028915405 +/- 0.16727785900075806
# test avg acc:  0.8294297337532044 +/- 0.0030537114908276704
# test avg auc:  0.8846362590789795 +/- 0.004138152854496341

# %%
t_eval = np.array(train_eval)
print("train avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("train avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("train avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# train avg loss:  0.19649080634117128 +/- 0.014047912461689311
# train avg acc:  0.8275829553604126 +/- 0.0031597352670844204
# train avg auc:  0.8824491262435913 +/- 0.004383806810878893
