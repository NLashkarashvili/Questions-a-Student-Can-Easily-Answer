# %%
import warnings
import gc
import random
import tensorflow as tf
from tensorflow import keras
from random import choice
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, GRU, Concatenate, Embedding, Flatten, Activation, Dropout
from sklearn.model_selection import KFold
from tensorflow.python.client import device_lib
warnings.filterwarnings('ignore')

# %%
MAXLENGTH = 13
EMBEDDING_DIM = 128

# %%
FEATURES_SIZE = 37
CHAPTER_SIZE = 38
SUB_CHAPTER_SIZE = 223
QUESTION_SIZE = 1069

# %%
import torch
X = np.array(grouped_data.keys())
kfold = KFold(n_splits=5, shuffle=True)
train_losses = list()
train_aucs = list()
val_losses = list()
val_aucs = list()
train_eval = list()
test_eval = list()
for train, test in kfold.split(X):
    users_train, users_test =  X[train], X[test]
    n = len(users_test)//2
    users_test, users_val = users_test[:n], users_test[n: ]
    train_data_space = SPACE_DATASET(grouped_data[users_train], MAXLENGTH)
    val_data_space = SPACE_DATASET(grouped_data[users_val], MAXLENGTH)
    test_data_space = SPACE_DATASET(grouped_data[users_test], MAXLENGTH)
    #construct training input
    train_chapter=[]
    train_sub_chapter=[]
    train_question = []
    train_features=[]
    train_shifted_t = []
    train_labels=[]
    for i in range(len(users_train)):
        user = train_data_space.__getitem__(i)
        train_chapter.append(user[0])
        train_sub_chapter.append(user[1]) 
        train_question.append(user[2])
        train_features.append(user[3])
        train_shifted_t.append(user[4])
        train_labels.append(user[5])
    train_chapter = np.array(train_chapter)
    train_sub_chapter = np.array(train_sub_chapter)
    train_question = np.array(train_question)
    train_features = np.array(train_features)
    train_shifted_t = np.array(train_shifted_t)
    train_labels= np.array(train_labels)[..., np.newaxis]

    #construct validation input
    val_chapter=[]
    val_sub_chapter=[]
    val_question = []
    val_features=[]
    val_shifted_t = []
    val_labels=[]
    for i in range(len(users_val)):
        user = val_data_space.__getitem__(i)
        val_chapter.append(user[0])
        val_sub_chapter.append(user[1]) 
        val_question.append(user[2])
        val_features.append(user[3])
        val_shifted_t.append(user[4])
        val_labels.append(user[5])
    val_chapter = np.array(val_chapter)
    val_sub_chapter = np.array(val_sub_chapter)
    val_features = np.array(val_features)
    val_question = np.array(val_question)
    val_shifted_t = np.array(val_shifted_t)
    val_labels= np.array(val_labels)[..., np.newaxis]

    # construct test input
    test_chapter=[]
    test_sub_chapter=[]
    test_features=[]
    test_question=[]
    test_shifted_t = []
    test_labels=[]
    for i in range(len(users_test)):
        user = test_data_space.__getitem__(i)
        test_chapter.append(user[0])
        test_sub_chapter.append(user[1]) 
        test_question.append(user[2])
        test_features.append(user[3])
        test_shifted_t.append(user[4])
        test_labels.append(user[5])
    test_chapter = np.array(test_chapter)
    test_sub_chapter = np.array(test_sub_chapter)
    test_features = np.array(test_features)
    test_question = np.array(test_question)
    test_shifted_t = np.array(test_shifted_t)
    test_labels= np.array(test_labels)[..., np.newaxis]

    # define loss function and evaluation metrics
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    acc = tf.keras.metrics.Accuracy()
    auc = tf.keras.metrics.AUC()

    def masked_bce(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return bce(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_acc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      flat_pred = (flat_pred >= 0.5)
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return acc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_auc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return auc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    # input layer
    input_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_sub_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_ques =  tf.keras.Input(shape=(MAXLENGTH))
    input_shifted = tf.keras.Input(shape=(MAXLENGTH))
    input_features = tf.keras.Input(shape=(MAXLENGTH, FEATURES_SIZE))

    # embedding layer for categorical features
    embedding_chap = Embedding(input_dim = CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_chap)
    embedding_sub_chap = Embedding(input_dim = SUB_CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_sub_chap) 
    embedding_ques = Embedding(input_dim = QUESTION_SIZE, output_dim = EMBEDDING_DIM)(input_ques)       
    embedding_shifted = Embedding(input_dim = 3, output_dim = EMBEDDING_DIM)(input_shifted)
    # dense layer for numeric features
    dense_features = Dense(EMBEDDING_DIM,input_shape = (None, MAXLENGTH))(input_features)
    
    output = tf.concat([embedding_chap, embedding_sub_chap, embedding_ques, embedding_shifted, dense_features], axis = 2)

    pred = Dense(1, input_shape = (None, 5*EMBEDDING_DIM), activation='sigmoid')(output)

    model = tf.keras.Model(
        inputs=[input_chap, input_sub_chap,input_ques, input_shifted, input_features],
        outputs=pred,
        name='logistic_regression'
    )

    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt_adam = Adam(learning_rate = 0.005)
    model.compile(
        optimizer=opt_adam,
        loss= masked_bce,
        metrics = [masked_acc, masked_auc]
    )

    history = model.fit(
      [train_chapter, train_sub_chapter, train_question, train_shifted_t, train_features],
      train_labels,
      batch_size = 64,
      epochs = 100,
      validation_data=([val_chapter, val_sub_chapter, val_question, val_shifted_t, val_features], val_labels),
      callbacks=[callback]
    )
    val_losses.append(list(history.history['val_loss']))
    train_losses.append(list(history.history['loss']))
    val_aucs.append(list(history.history['val_masked_auc']))
    train_aucs.append(list(history.history['masked_auc']))
    train_score = model.evaluate([train_chapter, train_sub_chapter, train_question, train_shifted_t, train_features], train_labels)
    train_eval.append(train_score)
    test_score = model.evaluate([test_chapter, test_sub_chapter, test_question, test_shifted_t, test_features], test_labels)
    test_eval.append(test_score)
    print("Test: ", test_score)
    def reset_weights(model):
      for layer in model.layers: 
        if isinstance(layer, tf.keras.Model):
          reset_weights(layer)
          continue
        for k, initializer in layer.__dict__.items():
          if "initializer" not in k:
            continue
          # find the corresponding variable
          var = getattr(layer, k.replace("_initializer", ""))
          var.assign(initializer(var.shape, var.dtype))
    reset_weights(model)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 3s 86ms/step - loss: 0.5767 - masked_acc: 0.6945 - masked_auc: 0.5432 - val_loss: 0.4886 - val_masked_acc: 0.7438 - val_masked_auc: 0.6720
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4567 - masked_acc: 0.7510 - masked_auc: 0.7048 - val_loss: 0.4710 - val_masked_acc: 0.7623 - val_masked_auc: 0.7500
# Epoch 3/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4119 - masked_acc: 0.7670 - masked_auc: 0.7642 - val_loss: 0.4789 - val_masked_acc: 0.7718 - val_masked_auc: 0.7797
# Epoch 4/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4200 - masked_acc: 0.7733 - masked_auc: 0.7857 - val_loss: 0.4814 - val_masked_acc: 0.7771 - val_masked_auc: 0.7946
# Epoch 5/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4096 - masked_acc: 0.7780 - masked_auc: 0.7984 - val_loss: 0.4922 - val_masked_acc: 0.7797 - val_masked_auc: 0.8032
# Epoch 6/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3998 - masked_acc: 0.7808 - masked_auc: 0.8060 - val_loss: 0.4897 - val_masked_acc: 0.7817 - val_masked_auc: 0.8093
# Epoch 7/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4037 - masked_acc: 0.7824 - masked_auc: 0.8114 - val_loss: 0.4885 - val_masked_acc: 0.7833 - val_masked_auc: 0.8138
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4063 - masked_acc: 0.7837 - masked_auc: 0.8151 - val_loss: 0.4984 - val_masked_acc: 0.7845 - val_masked_auc: 0.8171
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3997 - masked_acc: 0.7850 - masked_auc: 0.8184 - val_loss: 0.4966 - val_masked_acc: 0.7853 - val_masked_auc: 0.8196
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3959 - masked_acc: 0.7858 - masked_auc: 0.8208 - val_loss: 0.5017 - val_masked_acc: 0.7861 - val_masked_auc: 0.8216
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3951 - masked_acc: 0.7865 - masked_auc: 0.8227 - val_loss: 0.5028 - val_masked_acc: 0.7869 - val_masked_auc: 0.8233
# Epoch 12/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4019 - masked_acc: 0.7871 - masked_auc: 0.8239 - val_loss: 0.5038 - val_masked_acc: 0.7874 - val_masked_auc: 0.8247
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3988 - masked_acc: 0.7879 - masked_auc: 0.8262
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4781 - masked_acc: 0.7880 - masked_auc: 0.8267
# Test:  [0.47813862562179565, 0.7879844307899475, 0.8266651034355164]
# Epoch 1/100
# 14/14 [==============================] - 2s 72ms/step - loss: 0.6021 - masked_acc: 0.6019 - masked_auc: 0.5371 - val_loss: 0.5034 - val_masked_acc: 0.7232 - val_masked_auc: 0.6532
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4636 - masked_acc: 0.7337 - masked_auc: 0.6875 - val_loss: 0.4911 - val_masked_acc: 0.7499 - val_masked_auc: 0.7373
# Epoch 3/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4278 - masked_acc: 0.7544 - masked_auc: 0.7512 - val_loss: 0.4792 - val_masked_acc: 0.7624 - val_masked_auc: 0.7700
# Epoch 4/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4094 - masked_acc: 0.7654 - masked_auc: 0.7769 - val_loss: 0.4893 - val_masked_acc: 0.7685 - val_masked_auc: 0.7865
# Epoch 5/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4177 - masked_acc: 0.7699 - masked_auc: 0.7904 - val_loss: 0.4892 - val_masked_acc: 0.7726 - val_masked_auc: 0.7966
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4160 - masked_acc: 0.7735 - masked_auc: 0.7996 - val_loss: 0.4996 - val_masked_acc: 0.7754 - val_masked_auc: 0.8033
# Epoch 7/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4178 - masked_acc: 0.7759 - masked_auc: 0.8047 - val_loss: 0.4962 - val_masked_acc: 0.7776 - val_masked_auc: 0.8080
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4124 - masked_acc: 0.7783 - masked_auc: 0.8095 - val_loss: 0.5009 - val_masked_acc: 0.7792 - val_masked_auc: 0.8115
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4079 - masked_acc: 0.7797 - masked_auc: 0.8126 - val_loss: 0.5035 - val_masked_acc: 0.7805 - val_masked_auc: 0.8144
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4080 - masked_acc: 0.7809 - masked_auc: 0.8153 - val_loss: 0.5003 - val_masked_acc: 0.7815 - val_masked_auc: 0.8166
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4012 - masked_acc: 0.7819 - masked_auc: 0.8175 - val_loss: 0.5062 - val_masked_acc: 0.7825 - val_masked_auc: 0.8184
# Epoch 12/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3983 - masked_acc: 0.7829 - masked_auc: 0.8191 - val_loss: 0.5121 - val_masked_acc: 0.7830 - val_masked_auc: 0.8198
# Epoch 13/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4068 - masked_acc: 0.7833 - masked_auc: 0.8204 - val_loss: 0.5123 - val_masked_acc: 0.7837 - val_masked_auc: 0.8210
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4026 - masked_acc: 0.7843 - masked_auc: 0.8222
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4278 - masked_acc: 0.7849 - masked_auc: 0.8230
# Test:  [0.4278392493724823, 0.7848733067512512, 0.8230431079864502]
# Epoch 1/100
# 14/14 [==============================] - 2s 57ms/step - loss: 0.6063 - masked_acc: 0.5795 - masked_auc: 0.5470 - val_loss: 0.4814 - val_masked_acc: 0.7267 - val_masked_auc: 0.6609
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4474 - masked_acc: 0.7389 - masked_auc: 0.6999 - val_loss: 0.4722 - val_masked_acc: 0.7543 - val_masked_auc: 0.7441
# Epoch 3/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4194 - masked_acc: 0.7590 - masked_auc: 0.7573 - val_loss: 0.4750 - val_masked_acc: 0.7662 - val_masked_auc: 0.7764
# Epoch 4/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4054 - masked_acc: 0.7690 - masked_auc: 0.7834 - val_loss: 0.4794 - val_masked_acc: 0.7725 - val_masked_auc: 0.7925
# Epoch 5/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4041 - masked_acc: 0.7744 - masked_auc: 0.7965 - val_loss: 0.4865 - val_masked_acc: 0.7766 - val_masked_auc: 0.8023
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4000 - masked_acc: 0.7779 - masked_auc: 0.8050 - val_loss: 0.4891 - val_masked_acc: 0.7794 - val_masked_auc: 0.8086
# Epoch 7/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4028 - masked_acc: 0.7802 - masked_auc: 0.8106 - val_loss: 0.4916 - val_masked_acc: 0.7815 - val_masked_auc: 0.8132
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4135 - masked_acc: 0.7818 - masked_auc: 0.8141 - val_loss: 0.4933 - val_masked_acc: 0.7830 - val_masked_auc: 0.8166
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3949 - masked_acc: 0.7836 - masked_auc: 0.8181 - val_loss: 0.4992 - val_masked_acc: 0.7842 - val_masked_auc: 0.8194
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4064 - masked_acc: 0.7845 - masked_auc: 0.8201 - val_loss: 0.4972 - val_masked_acc: 0.7850 - val_masked_auc: 0.8216
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3973 - masked_acc: 0.7854 - masked_auc: 0.8225 - val_loss: 0.5030 - val_masked_acc: 0.7857 - val_masked_auc: 0.8234
# Epoch 12/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3986 - masked_acc: 0.7860 - masked_auc: 0.8241 - val_loss: 0.4999 - val_masked_acc: 0.7864 - val_masked_auc: 0.8249
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3978 - masked_acc: 0.7870 - masked_auc: 0.8264
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5144 - masked_acc: 0.7871 - masked_auc: 0.8266
# Test:  [0.5144180655479431, 0.7870545983314514, 0.8266248106956482]
# Epoch 1/100
# 14/14 [==============================] - 2s 57ms/step - loss: 0.5991 - masked_acc: 0.6120 - masked_auc: 0.5211 - val_loss: 0.5104 - val_masked_acc: 0.7264 - val_masked_auc: 0.6472
# Epoch 2/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4643 - masked_acc: 0.7370 - masked_auc: 0.6812 - val_loss: 0.5065 - val_masked_acc: 0.7522 - val_masked_auc: 0.7338
# Epoch 3/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4149 - masked_acc: 0.7577 - masked_auc: 0.7488 - val_loss: 0.5156 - val_masked_acc: 0.7634 - val_masked_auc: 0.7678
# Epoch 4/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4109 - masked_acc: 0.7661 - masked_auc: 0.7754 - val_loss: 0.5249 - val_masked_acc: 0.7696 - val_masked_auc: 0.7851
# Epoch 5/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4082 - masked_acc: 0.7712 - masked_auc: 0.7892 - val_loss: 0.5302 - val_masked_acc: 0.7735 - val_masked_auc: 0.7956
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4022 - masked_acc: 0.7751 - masked_auc: 0.7983 - val_loss: 0.5375 - val_masked_acc: 0.7762 - val_masked_auc: 0.8025
# Epoch 7/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4095 - masked_acc: 0.7768 - masked_auc: 0.8046 - val_loss: 0.5452 - val_masked_acc: 0.7780 - val_masked_auc: 0.8074
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4053 - masked_acc: 0.7785 - masked_auc: 0.8091 - val_loss: 0.5418 - val_masked_acc: 0.7794 - val_masked_auc: 0.8111
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4029 - masked_acc: 0.7798 - masked_auc: 0.8124 - val_loss: 0.5489 - val_masked_acc: 0.7806 - val_masked_auc: 0.8139
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4024 - masked_acc: 0.7810 - masked_auc: 0.8147 - val_loss: 0.5544 - val_masked_acc: 0.7815 - val_masked_auc: 0.8160
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4018 - masked_acc: 0.7819 - masked_auc: 0.8171 - val_loss: 0.5538 - val_masked_acc: 0.7823 - val_masked_auc: 0.8179
# Epoch 12/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4027 - masked_acc: 0.7826 - masked_auc: 0.8187 - val_loss: 0.5591 - val_masked_acc: 0.7830 - val_masked_auc: 0.8195
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3993 - masked_acc: 0.7837 - masked_auc: 0.8210
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4503 - masked_acc: 0.7840 - masked_auc: 0.8217
# Test:  [0.4503485858440399, 0.7840433716773987, 0.8217037916183472]
# Epoch 1/100
# 14/14 [==============================] - 2s 59ms/step - loss: 0.5933 - masked_acc: 0.6290 - masked_auc: 0.5195 - val_loss: 0.5312 - val_masked_acc: 0.7260 - val_masked_auc: 0.6530
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4479 - masked_acc: 0.7393 - masked_auc: 0.6898 - val_loss: 0.5386 - val_masked_acc: 0.7552 - val_masked_auc: 0.7393
# Epoch 3/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4140 - masked_acc: 0.7605 - masked_auc: 0.7528 - val_loss: 0.5446 - val_masked_acc: 0.7668 - val_masked_auc: 0.7730
# Epoch 4/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3984 - masked_acc: 0.7697 - masked_auc: 0.7800 - val_loss: 0.5532 - val_masked_acc: 0.7731 - val_masked_auc: 0.7898
# Epoch 5/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4086 - masked_acc: 0.7745 - masked_auc: 0.7940 - val_loss: 0.5605 - val_masked_acc: 0.7775 - val_masked_auc: 0.7999
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3883 - masked_acc: 0.7792 - masked_auc: 0.8032 - val_loss: 0.5659 - val_masked_acc: 0.7804 - val_masked_auc: 0.8069
# Epoch 7/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4053 - masked_acc: 0.7811 - masked_auc: 0.8090 - val_loss: 0.5718 - val_masked_acc: 0.7825 - val_masked_auc: 0.8114
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4066 - masked_acc: 0.7828 - masked_auc: 0.8130 - val_loss: 0.5735 - val_masked_acc: 0.7838 - val_masked_auc: 0.8149
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4027 - masked_acc: 0.7842 - masked_auc: 0.8161 - val_loss: 0.5796 - val_masked_acc: 0.7849 - val_masked_auc: 0.8175
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3953 - masked_acc: 0.7854 - masked_auc: 0.8187 - val_loss: 0.5778 - val_masked_acc: 0.7859 - val_masked_auc: 0.8198
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4008 - masked_acc: 0.7862 - masked_auc: 0.8205 - val_loss: 0.5843 - val_masked_acc: 0.7869 - val_masked_auc: 0.8217
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3897 - masked_acc: 0.7878 - masked_auc: 0.8235
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5065 - masked_acc: 0.7882 - masked_auc: 0.8244
# Test:  [0.5065282583236694, 0.7882015705108643, 0.8243522644042969]

# %%
t_eval = np.array(test_eval)
print("test avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("test avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("test avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# test avg loss:  0.4754545569419861 +/- 0.032828223969114764
# test avg acc:  0.7864314556121826 +/- 0.00167714747462835
# test avg auc:  0.8244778156280518 +/- 0.0019577116287155527

# %%
t_eval = np.array(train_eval)
print("train avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("train avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("train avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# train avg loss:  0.3976306736469269 +/- 0.004257601630885858
# train avg acc:  0.786148476600647 +/- 0.0017733387471380853
# train avg auc:  0.8238631129264832 +/- 0.0021479975188008634
