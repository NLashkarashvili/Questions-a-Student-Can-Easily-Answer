# %%
import warnings
import gc
import tensorflow as tf
from tensorflow import keras
from random import choice
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, GRU, Concatenate, Embedding, Flatten, Activation, Dropout
from sklearn.model_selection import KFold
from tensorflow.python.client import device_lib
warnings.filterwarnings('ignore')
import random

# %%
MAXLENGTH = 13
EMBEDDING_DIM = 128

# %%
FEATURES_SIZE = 37
CHAPTER_SIZE = 38
SUB_CHAPTER_SIZE = 223
QUESTION_SIZE = 1069

# %%
import torch
X = np.array(grouped_data.keys())
kfold = KFold(n_splits=5, shuffle=True)
train_losses = list()
train_aucs = list()
val_losses = list()
val_aucs = list()
train_eval = list()
test_eval = list()
for train, test in kfold.split(X):
    users_train, users_test =  X[train], X[test]
    n = len(users_test)//2
    users_test, users_val = users_test[:n], users_test[n: ]
    train_data_space = SPACE_DATASET(grouped_data[users_train], MAXLENGTH)
    val_data_space = SPACE_DATASET(grouped_data[users_val], MAXLENGTH)
    test_data_space = SPACE_DATASET(grouped_data[users_test], MAXLENGTH)
    #construct training input
    train_chapter=[]
    train_sub_chapter=[]
    train_question = []
    train_features=[]
    train_labels=[]
    for i in range(len(users_train)):
        user = train_data_space.__getitem__(i)
        train_chapter.append(user[0])
        train_sub_chapter.append(user[1]) 
        train_question.append(user[2])
        train_features.append(user[3])
        train_labels.append(user[4])
    train_chapter = np.array(train_chapter)
    train_sub_chapter = np.array(train_sub_chapter)
    train_question = np.array(train_question)
    train_features = np.array(train_features)
    train_labels= np.array(train_labels)[..., np.newaxis]

    #construct validation input
    val_chapter=[]
    val_sub_chapter=[]
    val_question = []
    val_features=[]
    val_labels=[]
    for i in range(len(users_val)):
        user = val_data_space.__getitem__(i)
        val_chapter.append(user[0])
        val_sub_chapter.append(user[1]) 
        val_question.append(user[2])
        val_features.append(user[3])
        val_labels.append(user[4])
    val_chapter = np.array(val_chapter)
    val_sub_chapter = np.array(val_sub_chapter)
    val_features = np.array(val_features)
    val_question = np.array(val_question)
    val_labels= np.array(val_labels)[..., np.newaxis]

    # construct test input
    test_chapter=[]
    test_sub_chapter=[]
    test_features=[]
    test_question=[]
    test_labels=[]
    for i in range(len(users_test)):
        user = test_data_space.__getitem__(i)
        test_chapter.append(user[0])
        test_sub_chapter.append(user[1]) 
        test_question.append(user[2])
        test_features.append(user[3])
        test_labels.append(user[4])
    test_chapter = np.array(test_chapter)
    test_sub_chapter = np.array(test_sub_chapter)
    test_features = np.array(test_features)
    test_question = np.array(test_question)
    test_labels= np.array(test_labels)[..., np.newaxis]

    # define loss function and evaluation metrics
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    acc = tf.keras.metrics.Accuracy()
    auc = tf.keras.metrics.AUC()

    def masked_bce(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return bce(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_acc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      flat_pred = (flat_pred >= 0.5)
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return acc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_auc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return auc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    # input layer
    input_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_sub_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_ques =  tf.keras.Input(shape=(MAXLENGTH))
    input_features = tf.keras.Input(shape=(MAXLENGTH, FEATURES_SIZE))

    # embedding layer for categorical features
    embedding_chap = Embedding(input_dim = CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_chap)
    embedding_sub_chap = Embedding(input_dim = SUB_CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_sub_chap) 
    embedding_ques = Embedding(input_dim = QUESTION_SIZE, output_dim = EMBEDDING_DIM)(input_ques)       
    # dense layer for numeric features
    dense_features = Dense(EMBEDDING_DIM,input_shape = (None, MAXLENGTH))(input_features)
    
    output = tf.concat([embedding_chap, embedding_sub_chap, embedding_ques, dense_features], axis = 2)

    pred = Dense(1, input_shape = (None, 4*EMBEDDING_DIM), activation='sigmoid')(output)

    model = tf.keras.Model(
        inputs=[input_chap, input_sub_chap,input_ques, input_features],
        outputs=pred,
        name='logistic_regression'
    )

    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt_adam = Adam(learning_rate = 0.005)
    model.compile(
        optimizer=opt_adam,
        loss= masked_bce,
        metrics = [masked_acc, masked_auc]
    )

    history = model.fit(
      [train_chapter, train_sub_chapter, train_question, train_features],
      train_labels,
      batch_size = 64,
      epochs = 100,
      validation_data=([val_chapter, val_sub_chapter, val_question, val_features], val_labels),
      callbacks=[callback]
    )
    val_losses.append(list(history.history['val_loss']))
    train_losses.append(list(history.history['loss']))
    val_aucs.append(list(history.history['val_masked_auc']))
    train_aucs.append(list(history.history['masked_auc']))
    train_score = model.evaluate([train_chapter, train_sub_chapter, train_question, train_features], train_labels)
    train_eval.append(train_score)
    test_score = model.evaluate([test_chapter, test_sub_chapter, test_question, test_features], test_labels)
    test_eval.append(test_score)
    print("Test: ", test_score)
    def reset_weights(model):
      for layer in model.layers: 
        if isinstance(layer, tf.keras.Model):
          reset_weights(layer)
          continue
        for k, initializer in layer.__dict__.items():
          if "initializer" not in k:
            continue
          # find the corresponding variable
          var = getattr(layer, k.replace("_initializer", ""))
          var.assign(initializer(var.shape, var.dtype))
    reset_weights(model)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 3s 89ms/step - loss: 0.6000 - masked_acc: 0.6136 - masked_auc: 0.5281 - val_loss: 0.5174 - val_masked_acc: 0.7241 - val_masked_auc: 0.6417
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4600 - masked_acc: 0.7346 - masked_auc: 0.6809 - val_loss: 0.5226 - val_masked_acc: 0.7482 - val_masked_auc: 0.7265
# Epoch 3/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4332 - masked_acc: 0.7530 - masked_auc: 0.7396 - val_loss: 0.5288 - val_masked_acc: 0.7592 - val_masked_auc: 0.7602
# Epoch 4/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4099 - masked_acc: 0.7623 - masked_auc: 0.7677 - val_loss: 0.5375 - val_masked_acc: 0.7650 - val_masked_auc: 0.7773
# Epoch 5/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4001 - masked_acc: 0.7672 - masked_auc: 0.7819 - val_loss: 0.5396 - val_masked_acc: 0.7684 - val_masked_auc: 0.7879
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4156 - masked_acc: 0.7692 - masked_auc: 0.7910 - val_loss: 0.5491 - val_masked_acc: 0.7709 - val_masked_auc: 0.7951
# Epoch 7/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4161 - masked_acc: 0.7715 - masked_auc: 0.7971 - val_loss: 0.5518 - val_masked_acc: 0.7728 - val_masked_auc: 0.7996
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4142 - masked_acc: 0.7733 - masked_auc: 0.8012 - val_loss: 0.5467 - val_masked_acc: 0.7743 - val_masked_auc: 0.8035
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4145 - masked_acc: 0.7748 - masked_auc: 0.8048 - val_loss: 0.5592 - val_masked_acc: 0.7754 - val_masked_auc: 0.8065
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4136 - masked_acc: 0.7759 - masked_auc: 0.8074 - val_loss: 0.5536 - val_masked_acc: 0.7764 - val_masked_auc: 0.8087
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3943 - masked_acc: 0.7771 - masked_auc: 0.8097 - val_loss: 0.5536 - val_masked_acc: 0.7772 - val_masked_auc: 0.8107
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4022 - masked_acc: 0.7778 - masked_auc: 0.8125
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4954 - masked_acc: 0.7783 - masked_auc: 0.8135
# Test:  [0.4953711926937103, 0.7782944440841675, 0.8134568333625793]
# Epoch 1/100
# 14/14 [==============================] - 2s 74ms/step - loss: 0.6034 - masked_acc: 0.5937 - masked_auc: 0.5459 - val_loss: 0.5270 - val_masked_acc: 0.7203 - val_masked_auc: 0.6451
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4584 - masked_acc: 0.7323 - masked_auc: 0.6843 - val_loss: 0.5382 - val_masked_acc: 0.7460 - val_masked_auc: 0.7298
# Epoch 3/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4268 - masked_acc: 0.7511 - masked_auc: 0.7437 - val_loss: 0.5417 - val_masked_acc: 0.7580 - val_masked_auc: 0.7632
# Epoch 4/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4250 - masked_acc: 0.7601 - masked_auc: 0.7701 - val_loss: 0.5454 - val_masked_acc: 0.7645 - val_masked_auc: 0.7797
# Epoch 5/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4065 - masked_acc: 0.7665 - masked_auc: 0.7836 - val_loss: 0.5604 - val_masked_acc: 0.7685 - val_masked_auc: 0.7897
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4108 - masked_acc: 0.7699 - masked_auc: 0.7928 - val_loss: 0.5557 - val_masked_acc: 0.7718 - val_masked_auc: 0.7968
# Epoch 7/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3972 - masked_acc: 0.7730 - masked_auc: 0.7993 - val_loss: 0.5584 - val_masked_acc: 0.7739 - val_masked_auc: 0.8018
# Epoch 8/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4049 - masked_acc: 0.7745 - masked_auc: 0.8036 - val_loss: 0.5654 - val_masked_acc: 0.7753 - val_masked_auc: 0.8056
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4034 - masked_acc: 0.7758 - masked_auc: 0.8069 - val_loss: 0.5736 - val_masked_acc: 0.7766 - val_masked_auc: 0.8084
# Epoch 10/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4091 - masked_acc: 0.7771 - masked_auc: 0.8095 - val_loss: 0.5755 - val_masked_acc: 0.7778 - val_masked_auc: 0.8107
# Epoch 11/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4070 - masked_acc: 0.7781 - masked_auc: 0.8116 - val_loss: 0.5788 - val_masked_acc: 0.7787 - val_masked_auc: 0.8125
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4028 - masked_acc: 0.7794 - masked_auc: 0.8142
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4946 - masked_acc: 0.7799 - masked_auc: 0.8151
# Test:  [0.4946192800998688, 0.7799015045166016, 0.8150550127029419]
# Epoch 1/100
# 14/14 [==============================] - 2s 59ms/step - loss: 0.6251 - masked_acc: 0.5936 - masked_auc: 0.5536 - val_loss: 0.5201 - val_masked_acc: 0.7202 - val_masked_auc: 0.6154
# Epoch 2/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4706 - masked_acc: 0.7311 - masked_auc: 0.6542 - val_loss: 0.5011 - val_masked_acc: 0.7451 - val_masked_auc: 0.7148
# Epoch 3/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4287 - masked_acc: 0.7505 - masked_auc: 0.7305 - val_loss: 0.4964 - val_masked_acc: 0.7562 - val_masked_auc: 0.7530
# Epoch 4/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4254 - masked_acc: 0.7586 - masked_auc: 0.7607 - val_loss: 0.4973 - val_masked_acc: 0.7625 - val_masked_auc: 0.7720
# Epoch 5/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4412 - masked_acc: 0.7631 - masked_auc: 0.7762 - val_loss: 0.5029 - val_masked_acc: 0.7662 - val_masked_auc: 0.7831
# Epoch 6/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4273 - masked_acc: 0.7670 - masked_auc: 0.7859 - val_loss: 0.5057 - val_masked_acc: 0.7687 - val_masked_auc: 0.7906
# Epoch 7/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4169 - masked_acc: 0.7695 - masked_auc: 0.7931 - val_loss: 0.5076 - val_masked_acc: 0.7706 - val_masked_auc: 0.7961
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4254 - masked_acc: 0.7710 - masked_auc: 0.7974 - val_loss: 0.5107 - val_masked_acc: 0.7721 - val_masked_auc: 0.7999
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4201 - masked_acc: 0.7726 - masked_auc: 0.8011 - val_loss: 0.5112 - val_masked_acc: 0.7736 - val_masked_auc: 0.8032
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4194 - masked_acc: 0.7738 - masked_auc: 0.8044 - val_loss: 0.5144 - val_masked_acc: 0.7745 - val_masked_auc: 0.8059
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4144 - masked_acc: 0.7749 - masked_auc: 0.8069 - val_loss: 0.5169 - val_masked_acc: 0.7753 - val_masked_auc: 0.8080
# Epoch 12/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4190 - masked_acc: 0.7754 - masked_auc: 0.8088 - val_loss: 0.5256 - val_masked_acc: 0.7759 - val_masked_auc: 0.8096
# Epoch 13/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4194 - masked_acc: 0.7762 - masked_auc: 0.8101 - val_loss: 0.5182 - val_masked_acc: 0.7765 - val_masked_auc: 0.8110
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4119 - masked_acc: 0.7771 - masked_auc: 0.8124
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4405 - masked_acc: 0.7774 - masked_auc: 0.8130
# Test:  [0.44049808382987976, 0.7773827314376831, 0.8130109310150146]
# Epoch 1/100
# 14/14 [==============================] - 2s 58ms/step - loss: 0.6429 - masked_acc: 0.5205 - masked_auc: 0.5327 - val_loss: 0.4912 - val_masked_acc: 0.7057 - val_masked_auc: 0.6266
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4724 - masked_acc: 0.7202 - masked_auc: 0.6630 - val_loss: 0.4943 - val_masked_acc: 0.7422 - val_masked_auc: 0.7192
# Epoch 3/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4343 - masked_acc: 0.7483 - masked_auc: 0.7340 - val_loss: 0.4888 - val_masked_acc: 0.7570 - val_masked_auc: 0.7555
# Epoch 4/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4274 - masked_acc: 0.7598 - masked_auc: 0.7631 - val_loss: 0.4920 - val_masked_acc: 0.7652 - val_masked_auc: 0.7746
# Epoch 5/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4135 - masked_acc: 0.7672 - masked_auc: 0.7790 - val_loss: 0.4984 - val_masked_acc: 0.7693 - val_masked_auc: 0.7856
# Epoch 6/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4159 - masked_acc: 0.7704 - masked_auc: 0.7887 - val_loss: 0.5045 - val_masked_acc: 0.7720 - val_masked_auc: 0.7929
# Epoch 7/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4145 - masked_acc: 0.7730 - masked_auc: 0.7951 - val_loss: 0.5006 - val_masked_acc: 0.7744 - val_masked_auc: 0.7982
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4122 - masked_acc: 0.7752 - masked_auc: 0.8001 - val_loss: 0.5037 - val_masked_acc: 0.7762 - val_masked_auc: 0.8024
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4175 - masked_acc: 0.7766 - masked_auc: 0.8037 - val_loss: 0.5033 - val_masked_acc: 0.7774 - val_masked_auc: 0.8055
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4079 - masked_acc: 0.7778 - masked_auc: 0.8067 - val_loss: 0.5070 - val_masked_acc: 0.7785 - val_masked_auc: 0.8081
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4057 - masked_acc: 0.7789 - masked_auc: 0.8091 - val_loss: 0.5071 - val_masked_acc: 0.7793 - val_masked_auc: 0.8103
# Epoch 12/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4030 - masked_acc: 0.7797 - masked_auc: 0.8111 - val_loss: 0.5128 - val_masked_acc: 0.7800 - val_masked_auc: 0.8120
# Epoch 13/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4049 - masked_acc: 0.7805 - masked_auc: 0.8127 - val_loss: 0.5039 - val_masked_acc: 0.7808 - val_masked_auc: 0.8135
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4077 - masked_acc: 0.7815 - masked_auc: 0.8149
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4812 - masked_acc: 0.7816 - masked_auc: 0.8155
# Test:  [0.4811649024486542, 0.7815752625465393, 0.8155335187911987]
# Epoch 1/100
# 14/14 [==============================] - 2s 57ms/step - loss: 0.5633 - masked_acc: 0.7429 - masked_auc: 0.5325 - val_loss: 0.5035 - val_masked_acc: 0.7481 - val_masked_auc: 0.6697
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4614 - masked_acc: 0.7534 - masked_auc: 0.7006 - val_loss: 0.4974 - val_masked_acc: 0.7645 - val_masked_auc: 0.7450
# Epoch 3/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4163 - masked_acc: 0.7686 - masked_auc: 0.7562 - val_loss: 0.5048 - val_masked_acc: 0.7717 - val_masked_auc: 0.7734
# Epoch 4/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4179 - masked_acc: 0.7732 - masked_auc: 0.7788 - val_loss: 0.5203 - val_masked_acc: 0.7749 - val_masked_auc: 0.7875
# Epoch 5/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4200 - masked_acc: 0.7754 - masked_auc: 0.7911 - val_loss: 0.5237 - val_masked_acc: 0.7775 - val_masked_auc: 0.7965
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4126 - masked_acc: 0.7783 - masked_auc: 0.7990 - val_loss: 0.5284 - val_masked_acc: 0.7793 - val_masked_auc: 0.8026
# Epoch 7/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4194 - masked_acc: 0.7796 - masked_auc: 0.8038 - val_loss: 0.5294 - val_masked_acc: 0.7804 - val_masked_auc: 0.8067
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4203 - masked_acc: 0.7805 - masked_auc: 0.8079 - val_loss: 0.5383 - val_masked_acc: 0.7813 - val_masked_auc: 0.8097
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4009 - masked_acc: 0.7820 - masked_auc: 0.8110 - val_loss: 0.5388 - val_masked_acc: 0.7825 - val_masked_auc: 0.8122
# Epoch 10/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4077 - masked_acc: 0.7828 - masked_auc: 0.8127 - val_loss: 0.5340 - val_masked_acc: 0.7831 - val_masked_auc: 0.8141
# Epoch 11/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4034 - masked_acc: 0.7834 - masked_auc: 0.8150 - val_loss: 0.5432 - val_masked_acc: 0.7838 - val_masked_auc: 0.8159
# Epoch 12/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4054 - masked_acc: 0.7840 - masked_auc: 0.8165 - val_loss: 0.5470 - val_masked_acc: 0.7843 - val_masked_auc: 0.8172
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3997 - masked_acc: 0.7850 - masked_auc: 0.8187
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5325 - masked_acc: 0.7849 - masked_auc: 0.8190
# Test:  [0.5325067639350891, 0.7849442958831787, 0.8189809322357178]

# %%
t_eval = np.array(test_eval)
print("test avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("test avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("test avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# test avg loss:  0.4888320446014404 +/- 0.02959287243245471
# test avg acc:  0.780419647693634 +/- 0.002676404678170294
# test avg auc:  0.8152074456214905 +/- 0.002109885325411076

# %%
t_eval = np.array(train_eval)
print("train avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("train avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("train avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# train avg loss:  0.4048603415489197 +/- 0.004389701083502058
# train avg acc:  0.7801926970481873 +/- 0.002856668467726358
# train avg auc:  0.8145319819450378 +/- 0.0023039965126862468
